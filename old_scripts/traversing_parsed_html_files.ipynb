# %% [markdown]
# # This is how to traverse through the files that will be returned from scraping team

# %%
# Import the os module, for the os.walk function
import os
 
# Set the directory you want to start from
rootDir = '.'
for dirName, subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        if ".html" in fname: 
            #This should be the scraping method
        if ".pdf" in fname:
            #This should be the pdf convertig method (http://stackoverflow.com/questions/25665/python-module-for-converting-pdf-to-text)
            #This should be the scraping method
# Out:
# Found directory: .
# 	beautiful_soup_intro.ipynb
# 	MS_extraction.ipynb
# 	README.md
# 	scraping_and_data_gathering.ipynb
# 	Untitled.ipynb
# 	untitled.txt
# Found directory: .\.git
# 	COMMIT_EDITMSG
# 	config
# 	description
# 	FETCH_HEAD
# 	HEAD
# 	index
# Found directory: .\.git\hooks
# 	applypatch-msg.sample
# 	commit-msg.sample
# 	post-update.sample
# 	pre-applypatch.sample
# 	pre-commit.sample
# 	pre-push.sample
# 	pre-rebase.sample
# 	prepare-commit-msg.sample
# 	update.sample
# Found directory: .\.git\info
# 	exclude
# Found directory: .\.git\logs
# 	HEAD
# Found directory: .\.git\logs\refs
# Found directory: .\.git\logs\refs\heads
# 	Akcan
# 	master
# Found directory: .\.git\logs\refs\remotes
# Found directory: .\.git\logs\refs\remotes\origin
# 	Akcan
# 	master
# Found directory: .\.git\objects
# Found directory: .\.git\objects\13
# 	faf7792fcbb9d4dca89ba92644fa9320e6daa3
# Found directory: .\.git\objects\1f
# 	f6ee5457677763ce972e6c84bb872fd0b48105
# ...

# %% [markdown]
# # List schools that haven't been successfully webscraped
#
# Author: Jaren Haber <br>
# Project Manager: Jaren Haber, PhD Candidate <br>
# Contact: jhaber@berkeley.edu
#
# Institution: University of California, Berkeley <br>
# Program: Undergraduate Research Apprentice Program (URAP) <br>
#
# Date created: November 8th, 2018 <br>
# Last modified: November 8th, 2018
#
# Description: For the purposes of improving our URL list and therefore our data collection, this script identifies two groups: schools with URLs that were not webscraped, and schools open in 2015 for which we didn't collect URLs (and therefore were also not webscraped). It produces a data file for each of these two groups of schools. Next steps: For the first group, the URLs will need to be hand-cleaned; for the second, URLs will need to be collected by hand.

# %% [markdown]
# ## Initialize

# %%
# Import packages
import pandas as pd
import numpy as np
import gc # For managing garbage collector

# %%
# Load data
gc.disable()
charterdf = pd.read_pickle('../../nowdata/charters_2015.pkl')
gc.enable()

print(charterdf.shape)
# Out:
# (10965, 704)

# %%
charterdf["NCESSCH"] = charterdf["NCESSCH"].astype(float) # Convert to float type (just in case)

# %%
# Sanity check: Show number of duplicates by NCESSCH:
print("# duplicates by NCESSCH: ", sum(charterdf.duplicated(subset=["NCESSCH"])))
# Out:
# # duplicates by NCESSCH:  0

# %% [markdown]
# ## Identify schools open in 2015-16 but NO URL
#
# No URL: `URL`.isna() or `URL`==""
#
# School open in 2015-16: <br>
# - `open:` SY_STATUS15 == 1,3,4,5 or 8  <br>
# - `closed:` SY_STATUS15 == 2,6 or 7

# %%
# Keep only those columns useful for URL collection:
nourl_df = charterdf[["SEARCH16", "URL", "NCESSCH", "SCHNAM16", "ADDRESS16", "SY_STATUS16", "SY_STATUS15", "LEVEL", "STABR", "WEBSITE", "YEAR_CLOSED", "SCH_NAME", "YEAR_OPENED"]]
print(nourl_df.shape)
list(nourl_df)
# Out:
# (10965, 13)
# ['SEARCH16',
#  'URL',
#  'NCESSCH',
#  'SCHNAM16',
#  'ADDRESS16',
#  'SY_STATUS16',
#  'SY_STATUS15',
#  'LEVEL',
#  'STABR',
#  'WEBSITE',
#  'YEAR_CLOSED',
#  'SCH_NAME',
#  'YEAR_OPENED']

# %%
# Keep ONLY those schools missing URLs (keep those with URL==0, which means school has no website, whether closed or whatever):
nourl1 = nourl_df[pd.isnull(nourl_df['URL'])] # Store rows where URL missing
nourl2 = nourl_df[nourl_df["URL"] == ''] # Store if URL an empty string

# Now concatenate these stored rows into one DF:
nourl_df = pd.concat([nourl1, nourl2])
print(nourl_df.shape)
# Out:
# (3828, 13)

# %%
# Filter to only open schools
filtered_STATUS = (nourl_df['SY_STATUS15'] == 1) | (nourl_df['SY_STATUS15'] == 3) | (nourl_df['SY_STATUS15'] == 4) | (nourl_df['SY_STATUS15'] == 5) | (nourl_df['SY_STATUS15'] == 8)

nourl_df = nourl_df.loc[filtered_STATUS]
print(nourl_df.shape)
nourl_df.head()
# Out:
# (402, 13)
#                                               SEARCH16  URL       NCESSCH  \
# 146  NORTHERN AZ ACADEMY FOR CAREER DEV. - WINSLOW ...  NaN  4.000770e+10
# 260  PEPE BARRON ACADEMY  2797 North Introspect Dri...  NaN  4.001250e+10
# 292  DISCOVERY PLUS ACADEMY  852 West 250 North , P...  NaN  4.001410e+10
# 386  THE SHELBY SCHOOL  249 W. Standage Drive , Pay...  NaN  4.002140e+10
# 516  PEPE BARRON MIDDLE SCHOOL  2797 N. Introspect ...  NaN  4.002960e+10
#
#                                           SCHNAM16  \
# 146  NORTHERN AZ ACADEMY FOR CAREER DEV. - WINSLOW
# 260                            PEPE BARRON ACADEMY
# 292                         DISCOVERY PLUS ACADEMY
# 386                              THE SHELBY SCHOOL
# 516                      PEPE BARRON MIDDLE SCHOOL
#
#                                              ADDRESS16  SY_STATUS16  \
# 146             502 Airport Road , Winslow AZ 86047.0           2.0
# 260   2797 North Introspect Drive , Tucson AZ 85745.0           1.0
# 292              852 West 250 North , Pima AZ 85543.0           1.0
# 386         249 W. Standage Drive , Payson AZ 85541.0           1.0
# 516      2797 N. Introspect Drive , Tucson AZ 85745.0           1.0
#
#      SY_STATUS15 LEVEL STABR                               WEBSITE  \
# 146          1.0     3    AZ            http://www.naacharter.org/
# 260          1.0     3    AZ                                   NaN
# 292          1.0     1    AZ  http://myweb.cableone.net/discplus1/
# 386          1.0     4    AZ                                   NaN
# 516          1.0     1    AZ                                   NaN
#
#      YEAR_CLOSED SCH_NAME  YEAR_OPENED
# 146       2016.0      NaN       1998.0
# 260          NaN      NaN       1998.0
# 292          NaN      NaN       1998.0
# 386          NaN      NaN       1999.0
# 516          NaN      NaN       2000.0

# %%
print("# duplicates by NCESSCH: ", sum(nourl_df.duplicated(subset='NCESSCH', keep='first')))

# Eliminate duplicates in pubschool data:
print("Removing duplicates...")
nourl_df = nourl_df.drop_duplicates(subset="NCESSCH", keep='first')

print("NEW # duplicates by NCESSCH: ", sum(nourl_df.duplicated(subset='NCESSCH', keep='first')))
# Out:
# # duplicates by NCESSCH:  0
# Removing duplicates...
# NEW # duplicates by NCESSCH:  0

# %%
print("#rows, #cols WITH empty by NCESSCH: ", nourl_df.shape)
nourl_df.dropna(subset=["NCESSCH"], inplace=True)
print("#rows, #cols WITHOUT empty by NCESSCH: ", nourl_df.shape)
# Out:
# #rows, #cols WITH empty by NCESSCH:  (402, 13)
# #rows, #cols WITHOUT empty by NCESSCH:  (402, 13)

# %%
list(nourl_df)
# Out:
# ['SEARCH16',
#  'URL',
#  'NCESSCH',
#  'SCHNAM16',
#  'ADDRESS16',
#  'SY_STATUS16',
#  'SY_STATUS15',
#  'LEVEL',
#  'STABR',
#  'WEBSITE',
#  'YEAR_CLOSED',
#  'SCH_NAME',
#  'YEAR_OPENED']

# %%
nourl_df
# Out:
#                                                 SEARCH16  URL       NCESSCH  \
# 146    NORTHERN AZ ACADEMY FOR CAREER DEV. - WINSLOW ...  NaN  4.000770e+10
# 260    PEPE BARRON ACADEMY  2797 North Introspect Dri...  NaN  4.001250e+10
# 292    DISCOVERY PLUS ACADEMY  852 West 250 North , P...  NaN  4.001410e+10
# 386    THE SHELBY SCHOOL  249 W. Standage Drive , Pay...  NaN  4.002140e+10
# 516    PEPE BARRON MIDDLE SCHOOL  2797 N. Introspect ...  NaN  4.002960e+10
# 519    VISIONS UNLIMITED ACADEMY  1275 East Barney La...  NaN  4.002990e+10
# 545    SOUTHSIDE COMMUNITY SCHOOL  2701 S. Campbell A...  NaN  4.003180e+10
# 632    CARPE DIEM COLLEGIATE HIGH SCHOOL DBA CARPE DI...  NaN  4.003810e+10
# 633     ISCHOOL2020  3777 W 22nd Lane , Yuma AZ 85364.0   NaN  4.003810e+10
# 647    LIFELONG LEARNING ACADEMY  3295 W. Orange Grov...  NaN  4.003930e+10
# 660    JEFFERSON ACADEMY OF ADVANCED LEARNING  40 Sou...  NaN  4.003980e+10
# 689    MOSAICA PREPARATORY ACADEMY OF CHANDLER  5835 ...  NaN  4.004180e+10
# 760    SEQUOIA REDWOOD CHARTER SCHOOL  6810 W. Thunde...  NaN  4.006370e+10
# 847    ACADEMY DEL SOL - HOPE  7102 W. Valley Crest P...  NaN  4.007970e+10
# 886    JACK THOMAN AIR AND SPACE ACADEMY AND PERFORMI...  NaN  4.008260e+10
# 887    DIGITAL TECHNOLOGY ACADEMY  1250 W. Continenta...  NaN  4.008260e+10
# 989    THE EARLY CAREER ACADEMY  5005 S. Wendler Dr. ...  NaN  4.009310e+10
# 990    SENECA PREPARATORY ACADEMY  601 E. Fort Lowell...  NaN  4.009320e+10
# 1152   ACADEMY OF ARTS AND SCIENCES: LOS ANGELES (9-1...  NaN  6.000011e+10
# 1159   ACADEMY OF ARTS AND SCIENCES: LOS ANGELES (K-8...  NaN  6.000011e+10
# 1220   WESTLAKE CHARTER MIDDLE  1985 Pebblewood Dr. ,...  NaN  6.000361e+10
# 1294   SAN FRANCISCO FLEX ACADEMY  1350 7th Ave. , Sa...  NaN  6.014111e+10
# 1312   THRIVE PUBLIC  4260 54th St. , San Diego CA 92...  NaN  6.014291e+10
# 1316   PARAMOUNT COLLEGIATE ACADEMY  4010 El Camino A...  NaN  6.014321e+10
# 1344   ACE ALUM ROCK  1990 Kammerer Ave , San Jose CA...  NaN  6.023101e+10
# 1394   OXFORD PREPARATORY ACADEMY - SAN DIEGO COUNTY ...  NaN  6.057001e+10
# 1555   VALLEY ARTS AND SCIENCE ACADEMY (VASA)  735 N....  NaN  6.145501e+10
# 1568   NORTH WOODS DISCOVERY  14732 Bass Dr. , Reddin...  NaN  6.149501e+10
# 1570   REDDING SCHOOL OF THE ARTS II  955 Inspiration...  NaN  6.149501e+10
# 1655   MID VALLEY ALTERNATIVE CHARTER  9895 Seventh A...  NaN  6.198900e+10
# ...                                                  ...  ...           ...
# 10929  JACINTO LOPEZ MARTINEZ  CALLE NORTE #200 , TOA...  NaN  7.200030e+11
# 10931  TERESA PRESTAMO  CARR 2 KM 24 HM 3  BO ESPINOS...  NaN  7.200030e+11
# 10932  ISAAC DEL ROSARIO  AVE FLOR DEL VALLE URB LAS ...  NaN  7.200030e+11
# 10933  SU NICOLAS RODRIGUEZ  CARR 568 KM 30 HM 1 BO P...  NaN  7.200030e+11
# 10934  DR. RAMON MELLADO PARSONS  CALLE 5 FINAL URB. ...  NaN  7.200030e+11
# 10935  MARIA LOPEZ PONCE  URB JARDINES DE COUNTRY CLU...  NaN  7.200030e+11
# 10936  FRANCISCO MATIAS LUGO  CALLE ALMENDRO VALLE AR...  NaN  7.200030e+11
# 10937  MARIA E. BAS DE VAZQUEZ  CARR 831 URB LOMAS VE...  NaN  7.200030e+11
# 10938  CARLOS ORAMA PADILLA  CALLE 10 URB MAGNOLIA GA...  NaN  7.200030e+11
# 10939  RAUL JULIA (FLAMBOYAN GARDENS)  CALLE 19 URB F...  NaN  7.200030e+11
# 10940  MIGUEL MELENDEZ MUNOZ  CARR 840 KM 1 HM 1 SECT...  NaN  7.200030e+11
# 10941  DR. SANTOS J. SEPULVEDA  URB SIERRA BAYAMON CA...  NaN  7.200030e+11
# 10942  ELEMENTAL RABANAL  CARR 722 BO RABANAL , AIBON...  NaN  7.200030e+11
# 10943  SU JOSE C. BARBOSA  CARR 14 KM 46 HM 5 BO ASOM...  NaN  7.200030e+11
# 10947  MICAELA ESCUDERO  CARR 2 KM 44 HM 4 BO CANTERA...  NaN  7.200030e+11
# 10948  CLEMENTE RAMIREZ ARELLANO  CARR 670 KM 4 HM 9 ...  NaN  7.200030e+11
# 10949  ANTONIO VELEZ ALVARADO  CARR 2 KM 46 HM 8 BO C...  NaN  7.200030e+11
# 10950  SU SALTO CABRA  CARR 566 KM 2 HM I BO SALTOS ,...  NaN  7.200030e+11
# 10951  SU SANAMUERTOS  CARR 157 KM 23 BO BARROS , ORO...  NaN  7.200030e+11
# 10952  SU DR. CAYETANO COLL Y TOSTE  CARR 638 HM 5 BO...  NaN  7.200030e+11
# 10954  ANTONIO PAOLI  URB SANTA RITA CALLE 9 V. ALTA ...  NaN  7.200030e+11
# 10955  ELISA DAVILA VAZQUEZ (ESPINOSA ADENTRO)  CARR ...  NaN  7.200030e+11
# 10956  ANGEL SANDIN MARTINEZ  4 CALLE JULIO OTERO ESQ...  NaN  7.200030e+11
# 10957  EUGENIO MARIA DE HOSTOS  CARR 155 KM 59 HM 9 B...  NaN  7.200030e+11
# 10959  RAMON E. RODRIGUEZ DIAZ  CALLE COMERCIO URB. V...  NaN  7.200030e+11
# 10960  RAMON DE JESUS SIERRA  AVE LOS PATRIOTAS , LAR...  NaN  7.200030e+11
# 10961  EMILIO SCHARON RODRIGUEZ  CARR. 111 KM.1.9 BO....  NaN  7.200030e+11
# 10962  RVDO FELIX CASTRO RODRIGUEZ  CALLE 612 AVE CAM...  NaN  7.200030e+11
# 10963  MERCEDES ROSADO  CARR 152 CALLE GEORGETTY , NA...  NaN  7.200030e+11
# 10964  CELSO GONZALEZ VAILLANT  CARR 188 KM 7 HM 2 , ...  NaN  7.200030e+11
#
#                                                 SCHNAM16  \
# 146        NORTHERN AZ ACADEMY FOR CAREER DEV. - WINSLOW
# 260                                  PEPE BARRON ACADEMY
# 292                               DISCOVERY PLUS ACADEMY
# 386                                    THE SHELBY SCHOOL
# 516                            PEPE BARRON MIDDLE SCHOOL
# 519                            VISIONS UNLIMITED ACADEMY
# 545                           SOUTHSIDE COMMUNITY SCHOOL
# 632    CARPE DIEM COLLEGIATE HIGH SCHOOL DBA CARPE DI...
# 633                                          ISCHOOL2020
# 647                            LIFELONG LEARNING ACADEMY
# 660               JEFFERSON ACADEMY OF ADVANCED LEARNING
# 689              MOSAICA PREPARATORY ACADEMY OF CHANDLER
# 760                       SEQUOIA REDWOOD CHARTER SCHOOL
# 847                               ACADEMY DEL SOL - HOPE
# 886    JACK THOMAN AIR AND SPACE ACADEMY AND PERFORMI...
# 887                           DIGITAL TECHNOLOGY ACADEMY
# 989                             THE EARLY CAREER ACADEMY
# 990                           SENECA PREPARATORY ACADEMY
# 1152    ACADEMY OF ARTS AND SCIENCES: LOS ANGELES (9-12)
# 1159     ACADEMY OF ARTS AND SCIENCES: LOS ANGELES (K-8)
# 1220                             WESTLAKE CHARTER MIDDLE
# 1294                          SAN FRANCISCO FLEX ACADEMY
# 1312                                       THRIVE PUBLIC
# 1316                        PARAMOUNT COLLEGIATE ACADEMY
# 1344                                       ACE ALUM ROCK
# 1394       OXFORD PREPARATORY ACADEMY - SAN DIEGO COUNTY
# 1555              VALLEY ARTS AND SCIENCE ACADEMY (VASA)
# 1568                               NORTH WOODS DISCOVERY
# 1570                       REDDING SCHOOL OF THE ARTS II
# 1655                      MID VALLEY ALTERNATIVE CHARTER
# ...                                                  ...
# 10929                             JACINTO LOPEZ MARTINEZ
# 10931                                    TERESA PRESTAMO
# 10932                                  ISAAC DEL ROSARIO
# 10933                               SU NICOLAS RODRIGUEZ
# 10934                          DR. RAMON MELLADO PARSONS
# 10935                                  MARIA LOPEZ PONCE
# 10936                              FRANCISCO MATIAS LUGO
# 10937                            MARIA E. BAS DE VAZQUEZ
# 10938                               CARLOS ORAMA PADILLA
# 10939                     RAUL JULIA (FLAMBOYAN GARDENS)
# 10940                              MIGUEL MELENDEZ MUNOZ
# 10941                            DR. SANTOS J. SEPULVEDA
# 10942                                  ELEMENTAL RABANAL
# 10943                                 SU JOSE C. BARBOSA
# 10947                                   MICAELA ESCUDERO
# 10948                          CLEMENTE RAMIREZ ARELLANO
# 10949                             ANTONIO VELEZ ALVARADO
# 10950                                     SU SALTO CABRA
# 10951                                     SU SANAMUERTOS
# 10952                       SU DR. CAYETANO COLL Y TOSTE
# 10954                                      ANTONIO PAOLI
# 10955            ELISA DAVILA VAZQUEZ (ESPINOSA ADENTRO)
# 10956                              ANGEL SANDIN MARTINEZ
# 10957                            EUGENIO MARIA DE HOSTOS
# 10959                            RAMON E. RODRIGUEZ DIAZ
# 10960                              RAMON DE JESUS SIERRA
# 10961                           EMILIO SCHARON RODRIGUEZ
# 10962                        RVDO FELIX CASTRO RODRIGUEZ
# 10963                                    MERCEDES ROSADO
# 10964                            CELSO GONZALEZ VAILLANT
#
#                                                ADDRESS16  SY_STATUS16  \
# 146               502 Airport Road , Winslow AZ 86047.0           2.0
# 260     2797 North Introspect Drive , Tucson AZ 85745.0           1.0
# 292                852 West 250 North , Pima AZ 85543.0           1.0
# 386           249 W. Standage Drive , Payson AZ 85541.0           1.0
# 516        2797 N. Introspect Drive , Tucson AZ 85745.0           1.0
# 519           1275 East Barney Lane , Benson AZ 85602.0           1.0
# 545            2701 S. Campbell Ave , Tucson AZ 85713.0           1.0
# 632                 3777 W. 22nd Lane , Yuma AZ 85364.0           1.0
# 633                  3777 W 22nd Lane , Yuma AZ 85364.0           1.0
# 647            3295 W. Orange Grove , Tucson AZ 85741.0           1.0
# 660          40 South 11th Street , Show Low AZ 85901.0           2.0
# 689            5835 West Ray Road , Chandler AZ 85226.0           2.0
# 760         6810 W. Thunderbird Rd. , Peoria AZ 85048.0           1.0
# 847         7102 W. Valley Crest Pl , Tucson AZ 85757.0           1.0
# 886     730 W. Calle Arroyo Sur , Green Valley AZ 856...          1.0
# 887     1250 W. Continental RD. , Green Valley AZ 856...          2.0
# 989              5005 S. Wendler Dr. , Tempe AZ 85248.0           6.0
# 990        601 E. Fort Lowell Blvd. , Tucson AZ 85705.0           6.0
# 1152            17500 Burbank Blvd. , Encino CA 91361.0           2.0
# 1159             17500 Burbank Blvd , Encino CA 91361.0           2.0
# 1220        1985 Pebblewood Dr. , Sacramento CA 95834.0           2.0
# 1294           1350 7th Ave. , San Francisco CA 94122.0           2.0
# 1312               4260 54th St. , San Diego CA 92115.0           2.0
# 1316        4010 El Camino Ave. , Sacramento CA 95821.0           1.0
# 1344            1990 Kammerer Ave , San Jose CA 95116.0           2.0
# 1394     2281 Diegueno Dr. , Borrego Springs CA 92004.0           2.0
# 1555              735 N. Glenn Ave. , Fresno CA 93728.0           2.0
# 1568                14732 Bass Dr. , Redding CA 96003.0           2.0
# 1570           955 Inspiration Pl. , Redding CA 96002.0           2.0
# 1655             9895 Seventh Ave. , Hanford CA 93230.0           1.0
# ...                                                  ...          ...
# 10929              CALLE NORTE #200 , TOA BAJA PR 646.0           1.0
# 10931   CARR 2 KM 24 HM 3  BO ESPINOSA , DORADO PR 64...          1.0
# 10932   AVE FLOR DEL VALLE URB LAS VEG , CATANO PR 96...          1.0
# 10933   CARR 568 KM 30 HM 1 BO PADILLA , COROZAL PR 7...          1.0
# 10934   CALLE 5 FINAL URB. SABANA GARD , CAROLINA PR ...          1.0
# 10935   URB JARDINES DE COUNTRY CLUB C , CAROLINA PR ...          1.0
# 10936   CALLE ALMENDRO VALLE ARRIBA HI , CAROLINA PR ...          1.0
# 10937      CARR 831 URB LOMAS VERDES , BAYAMON PR 956.0           1.0
# 10938   CALLE 10 URB MAGNOLIA GARDENS , BAYAMON PR 95...          1.0
# 10939   CALLE 19 URB FLAMBOYAN GARDENS , BAYAMON PR 9...          1.0
# 10940   CARR 840 KM 1 HM 1 SECTOR LA A , BAYAMON PR 9...          1.0
# 10941    URB SIERRA BAYAMON CALLE 33 , BAYAMON PR 961.0           1.0
# 10942           CARR 722 BO RABANAL , AIBONITO PR 705.0           1.0
# 10943   CARR 14 KM 46 HM 5 BO ASOMANTE , AIBONITO PR ...          1.0
# 10947    CARR 2 KM 44 HM 4 BO CANTERA , MANATI PR 674.0           1.0
# 10948   CARR 670 KM 4 HM 9 BO PUEBLITO , MANATI PR 67...          1.0
# 10949   CARR 2 KM 46 HM 8 BO CAMPO ALE , MANATI PR 67...          1.0
# 10950   CARR 566 KM 2 HM I BO SALTOS , OROCOVIS PR 72...          1.0
# 10951      CARR 157 KM 23 BO BARROS , OROCOVIS PR 720.0           1.0
# 10952    CARR 638 HM 5 BO MIRAFLORES , ARECIBO PR 612.0           1.0
# 10954   URB SANTA RITA CALLE 9 V. ALTA , VEGA ALTA PR...          1.0
# 10955   CARR 679 KM 2 HM 3 SECT FORTUN , VEGA ALTA PR...          1.0
# 10956   4 CALLE JULIO OTERO ESQ JOSE A , VEGA BAJA PR...          1.0
# 10957   CARR 155 KM 59 HM 9 BO PUGNADO , VEGA BAJA PR...          1.0
# 10959   CALLE COMERCIO URB. VERDUN , HORMIGUEROS PR 6...          1.0
# 10960                AVE LOS PATRIOTAS , LARES PR 669.0           1.0
# 10961   CARR. 111 KM.1.9 BO.HOYAMALA , SAN SEBASTIAN ...          2.0
# 10962   CALLE 612 AVE CAMPO RICO FINAL , CAROLINA PR ...          1.0
# 10963     CARR 152 CALLE GEORGETTY , NARANJITO PR 719.0           1.0
# 10964               CARR 188 KM 7 HM 2 , LOIZA PR 772.0           1.0
#
#        SY_STATUS15 LEVEL STABR                               WEBSITE  \
# 146            1.0     3    AZ            http://www.naacharter.org/
# 260            1.0     3    AZ                                   NaN
# 292            1.0     1    AZ  http://myweb.cableone.net/discplus1/
# 386            1.0     4    AZ                                   NaN
# 516            1.0     1    AZ                                   NaN
# 519            1.0     1    AZ           VisionsUnlimitedAcademy.com
# 545            1.0     4    AZ                                   NaN
# 632            1.0     4    AZ                                   NaN
# 633            1.0     3    AZ                                   NaN
# 647            1.0     1    AZ                                   NaN
# 660            1.0     4    AZ             www.Jefferson-Academy.com
# 689            1.0     4    AZ                                   NaN
# 760            1.0     1    AZ                    azconservatory.org
# 847            1.0     1    AZ                                   NaN
# 886            1.0     1    AZ                            https//www
# 887            1.0     1    AZ            www.airandspaceacademy.com
# 989            3.0     3    AZ                                   NaN
# 990            3.0     1    AZ                                   NaN
# 1152           1.0     3    CA                 www.aascalifornia.org
# 1159           1.0     1    CA                 www.aascalifornia.org
# 1220           1.0     2    CA               www.westlakecharter.com
# 1294           1.0     4    CA                        www.sfflex.org
# 1312           1.0     1    CA                      www.thriveps.org
# 1316           3.0     4    CA                  www.pcaeducation.org
# 1344           1.0     2    CA                    www.acecharter.org
# 1394           1.0     4    CA               www.oxfordchampions.org
# 1555           1.0     1    CA                www.vasaelementary.com
# 1568           1.0     1    CA                                   NaN
# 1570           1.0     1    CA                        www.rsarts.org
# 1655           1.0     1    CA               www.kitcarsonschool.com
# ...            ...   ...   ...                                   ...
# 10929          1.0     1    PR                                   NaN
# 10931          1.0     1    PR                                   NaN
# 10932          1.0     1    PR                                   NaN
# 10933          1.0     1    PR                                   NaN
# 10934          1.0     1    PR                                   NaN
# 10935          1.0     1    PR                                   NaN
# 10936          1.0     1    PR                                   NaN
# 10937          1.0     1    PR                                   NaN
# 10938          1.0     1    PR                                   NaN
# 10939          1.0     1    PR                                   NaN
# 10940          1.0     3    PR                                   NaN
# 10941          1.0     1    PR                                   NaN
# 10942          1.0     1    PR                                   NaN
# 10943          1.0     4    PR                                   NaN
# 10947          1.0     1    PR                                   NaN
# 10948          1.0     1    PR                                   NaN
# 10949          1.0     1    PR                                   NaN
# 10950          1.0     1    PR                                   NaN
# 10951          1.0     1    PR                                   NaN
# 10952          1.0     4    PR                                   NaN
# 10954          1.0     1    PR                                   NaN
# 10955          1.0     1    PR                                   NaN
# 10956          1.0     2    PR                                   NaN
# 10957          1.0     1    PR                                   NaN
# 10959          1.0     2    PR                                   NaN
# 10960          1.0     2    PR                                   NaN
# 10961          1.0     3    PR                                   NaN
# 10962          1.0     2    PR                                   NaN
# 10963          1.0     2    PR                                   NaN
# 10964          1.0     1    PR                                   NaN
#
#        YEAR_CLOSED                        SCH_NAME  YEAR_OPENED
# 146         2016.0                             NaN       1998.0
# 260            NaN                             NaN       1998.0
# 292            NaN                             NaN       1998.0
# 386            NaN                             NaN       1999.0
# 516            NaN                             NaN       2000.0
# 519            NaN                             NaN       2000.0
# 545            NaN                             NaN       2000.0
# 632            NaN                             NaN       2002.0
# 633            NaN                             NaN       2007.0
# 647            NaN                             NaN       2002.0
# 660         2016.0                             NaN       2002.0
# 689         2016.0                             NaN       2004.0
# 760            NaN  SEQUOIA REDWOOD CHARTER SCHOOL       2004.0
# 847            NaN                             NaN       2010.0
# 886            NaN                             NaN       2010.0
# 887         2016.0                             NaN       2011.0
# 989            NaN                             NaN       2015.0
# 990            NaN                             NaN       2015.0
# 1152        2016.0                             NaN       2014.0
# 1159        2016.0                             NaN       2014.0
# 1220        2016.0                             NaN       2011.0
# 1294        2016.0                             NaN       2010.0
# 1312        2016.0                             NaN       2015.0
# 1316           NaN                             NaN       2015.0
# 1344        2016.0                             NaN       2014.0
# 1394        2016.0                             NaN       2013.0
# 1555        2016.0                             NaN       2006.0
# 1568        2016.0                             NaN       2001.0
# 1570        2016.0                             NaN       2007.0
# 1655        2010.0                             NaN       1998.0
# ...            ...                             ...          ...
# 10929          NaN                             NaN       1998.0
# 10931          NaN                             NaN       1998.0
# 10932          NaN                             NaN       1998.0
# 10933          NaN                             NaN       1998.0
# 10934          NaN                             NaN       1998.0
# 10935          NaN                             NaN       1998.0
# 10936          NaN                             NaN       1998.0
# 10937          NaN                             NaN       1998.0
# 10938          NaN                             NaN       1998.0
# 10939          NaN                             NaN       1998.0
# 10940          NaN                             NaN       1998.0
# 10941          NaN                             NaN       1998.0
# 10942          NaN                             NaN       1998.0
# 10943          NaN                             NaN       1998.0
# 10947          NaN                             NaN       1998.0
# 10948          NaN                             NaN       1998.0
# 10949          NaN                             NaN       1998.0
# 10950          NaN                             NaN       1998.0
# 10951          NaN                             NaN       1998.0
# 10952          NaN                             NaN       1998.0
# 10954          NaN                             NaN       1998.0
# 10955          NaN                             NaN       1998.0
# 10956          NaN                             NaN       1998.0
# 10957          NaN                             NaN       1998.0
# 10959          NaN                             NaN       1998.0
# 10960          NaN                             NaN       1998.0
# 10961       2016.0                             NaN       1998.0
# 10962          NaN                             NaN       1998.0
# 10963          NaN                             NaN       1998.0
# 10964          NaN                             NaN       1998.0
#
# [402 rows x 13 columns]

# %% [markdown]
# ## Identify schools with URLs that weren't webscraped
#
# Not scraped: `WEBTEXT`  length == 0
#
# Has URL: `URL`.isnull()==False (or use dropna) and `URL`!=""

# %%
# Load data
gc.disable()
charterdf = pd.read_pickle('../../nowdata/charters_2015.pkl')
gc.enable()

print(charterdf.shape)
# Out:
# (10965, 704)

# %%
# Drop schools missing URLs (keep those with URL==0, which means school has no website, whether closed or whatever):
charterdf = charterdf.dropna(subset = ['URL']) # drop if URL missing
charterdf = charterdf[charterdf["URL"] != ''] # drop if URL an empty string
print(charterdf.shape)
list(charterdf)
# Out:
# (7137, 702)
# ['NCESSCH',
#  'URL',
#  'LAT1516',
#  'LON1516',
#  'AM',
#  'AS',
#  'BL',
#  'HI',
#  'HP',
#  'TR',
#  'TOTFRL',
#  'CHARTER_TEXT',
#  'WEBSITE',
#  'MEMBER',
#  'LEVEL',
#  'LOCALE15',
#  'LEAID',
#  'LSTREET1',
#  'LSTREET2',
#  'LSTREET3',
#  'LCITY',
#  'LSTATE',
#  'LZIP',
#  'CMO_NAME',
#  'CMO_MEMSUM',
#  'SCH_NAME',
#  'CMO_STATE',
#  'CMO_SCHNUM',
#  'CMO_URL',
#  'CMO_NUMSTATES',
#  'CMO_ALLSTATES',
#  'CMO_SECTOR',
#  'CMO_NUMSTUDENTS_CREDO17',
#  'CMO_TYPE',
#  'SURVYEAR',
#  'FIPST',
#  'STABR',
#  'SEANAME',
#  'ST_LEAID',
#  'SCHID',
#  'ST_SCHID',
#  'MSTREET1',
#  'MSTREET2',
#  'MSTREET3',
#  'MCITY',
#  'MSTATE',
#  'MZIP',
#  'MZIP4',
#  'PHONE',
#  'LZIP4',
#  'UNION',
#  'OUT_OF_STATE_FLAG',
#  'SCH_TYPE_TEXT',
#  'SCH_TYPE',
#  'RECON_STATUS',
#  'GSLO',
#  'GSHI',
#  'VIRTUAL',
#  'BIES',
#  'SY_STATUS_TEXT',
#  'SY_STATUS',
#  'UPDATED_STATUS_TEXT',
#  'UPDATED_STATUS',
#  'EFFECTIVE_DATE',
#  'G13OFFERED',
#  'AEOFFERED',
#  'UGOFFERED',
#  'NOGRADES',
#  'CHARTAUTH1',
#  'CHARTAUTHN1',
#  'CHARTAUTH2',
#  'CHARTAUTHN2',
#  'IGOFFERED',
#  'FRELCH',
#  'REDLCH',
#  'AE',
#  'TOTAL',
#  'AMALM',
#  'AMALF',
#  'ASALM',
#  'ASALF',
#  'HIALM',
#  'HIALF',
#  'BLALM',
#  'BLALF',
#  'WH',
#  'WHALM',
#  'WHALF',
#  'HPALM',
#  'HPALF',
#  'TRALM',
#  'TRALF',
#  'TITLEI_TEXT',
#  'TITLEI_STATUS',
#  'STITLEI',
#  'SHARED_TIME',
#  'MAGNET_TEXT',
#  'NSLPSTATUS_TEXT',
#  'NSLPSTATUS_CODE',
#  'NAME',
#  'OPSTFIPS',
#  'LSTREE',
#  'STFIP15',
#  'CNTY15',
#  'NMCNTY15',
#  'CBSA15',
#  'NMCBSA15',
#  'CBSATYPE15',
#  'CSA15',
#  'NMCSA15',
#  'NECTA15',
#  'NMNECTA15',
#  'CD15',
#  'SLDL15',
#  'SLDU15',
#  'LSTREET114',
#  'LSTREET214',
#  'LSTREET314',
#  'LCITY14',
#  'LSTATE14',
#  'LZIP14',
#  'ISFLE',
#  'ISFTEPUP',
#  'SCHNAM98',
#  'CHARTR98',
#  'STATUS98',
#  'SCHNAM99',
#  'CHARTR99',
#  'STATUS99',
#  'SCHNAM00',
#  'CHARTR00',
#  'STATUS00',
#  'SCHNAM01',
#  'CHARTR01',
#  'STATUS01',
#  'SCHNAM02',
#  'CHARTR02',
#  'STATUS02',
#  'SCHNAM03',
#  'CHARTR03',
#  'STATUS03',
#  'SCHNAM04',
#  'CHARTR04',
#  'STATUS04',
#  'SCHNAM05',
#  'CHARTR05',
#  'STATUS05',
#  'SCHNAM06',
#  'CHARTR06',
#  'STATUS06',
#  'SCHNAM07',
#  'CHARTR07',
#  'STATUS07',
#  'SCHNAM08',
#  'CHARTR08',
#  'STATUS08',
#  'SCHNAM09',
#  'CHARTR09',
#  'STATUS09',
#  'SCHNAM10',
#  'CHARTR10',
#  'STATUS10',
#  'RECONSTY10',
#  'RECONSTF10',
#  'SCHNAM11',
#  'CHARTR11',
#  'STATUS11',
#  'RECONSTY11',
#  'RECONSTF11',
#  'SCHNAM12',
#  'CHARTR12',
#  'STATUS12',
#  'RECONSTY12',
#  'RECONSTF12',
#  'SCHNAM13',
#  'CHARTR13',
#  'STATUS13',
#  'RECONSTY13',
#  'RECONSTF13',
#  'SCHNAM15',
#  'CHARTER_TEXT15',
#  'SY_STATUS15',
#  'RECON_STATUS15',
#  'SCHNAM16',
#  'CHARTER_TEXT16',
#  'SY_STATUS16',
#  'RECON_STATUS16',
#  'PVI2017',
#  'PVI2014',
#  'CONUM',
#  'CONAME',
#  'CD',
#  'CBSA',
#  'CSA',
#  'NECTA',
#  'METMIC',
#  'ALL_MTH00NUMVALID_1415',
#  'ALL_RLA00NUMVALID_1415',
#  'LSTREET116',
#  'LSTREET216',
#  'LSTREET316',
#  'LCITY16',
#  'LSTATE16',
#  'LZIP16',
#  'ADDRESS16',
#  'ALL_RLA00NUMVALID_1516',
#  'ALL_RLA00PCTPROF_1516',
#  'ALL_MTH00NUMVALID_1516',
#  'ALL_MTH00PCTPROF_1516',
#  'ess_strength_x',
#  'prog_strength_x',
#  'SD_lv_PVI_2014',
#  'SD_lv_PVI_2017',
#  'Geo_FIPS',
#  'Geo_NAME',
#  'Geo_QName',
#  'Geo_STUSAB',
#  'Geo_SUMLEV',
#  'Geo_FILEID',
#  'Geo_LOGRECNO',
#  'Geo_STATE',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_GEOID',
#  'SE_T002_003',
#  'Geo_AREAWATR',
#  'SE_T002_001',
#  'SE_T002_002',
#  'PCT_SE_T009_002',
#  'PCT_SE_T009_003',
#  'PCT_SE_T009_004',
#  'PCT_SE_T009_005',
#  'PCT_SE_T013_002',
#  'PCT_SE_T013_003',
#  'PCT_SE_T013_004',
#  'PCT_SE_T013_005',
#  'PCT_SE_T013_006',
#  'PCT_SE_T013_007',
#  'PCT_SE_T013_008',
#  'SE_T165_001',
#  'PCT_SE_T165_002',
#  'PCT_SE_T165_003',
#  'PCT_SE_T165_016',
#  'PCT_SE_T165_017',
#  'PCT_SE_T167_002',
#  'PCT_SE_T167_008',
#  'SE_T022_001',
#  'PCT_SE_T022_002',
#  'PCT_SE_T022_003',
#  'PCT_SE_T022_004',
#  'PCT_SE_T022_005',
#  'PCT_SE_T022_006',
#  'SE_T025_001',
#  'PCT_SE_T025_002',
#  'PCT_SE_T025_003',
#  'PCT_SE_T025_004',
#  'PCT_SE_T025_005',
#  'PCT_SE_T025_006',
#  'PCT_SE_T025_007',
#  'PCT_SE_T025_008',
#  'SE_T028_001',
#  'PCT_SE_T028_002',
#  'PCT_SE_T028_003',
#  'PCT_SE_T029_002',
#  'PCT_SE_T029_003',
#  'PCT_SE_T029_004',
#  'PCT_SE_T029_005',
#  'PCT_SE_T029_006',
#  'PCT_SE_T029_007',
#  'PCT_SE_T029_008',
#  'PCT_SE_T029_009',
#  'PCT_SE_T029_010',
#  'PCT_SE_T029_011',
#  'SE_T030_001',
#  'PCT_SE_T030_002',
#  'PCT_SE_T030_003',
#  'PCT_SE_T037_002',
#  'PCT_SE_T037_003',
#  'PCT_SE_T048_002',
#  'PCT_SE_T048_003',
#  'PCT_SE_T049_002',
#  'PCT_SE_T049_003',
#  'PCT_SE_T049_004',
#  'PCT_SE_T049_005',
#  'PCT_SE_T049_006',
#  'PCT_SE_T049_007',
#  'PCT_SE_T049_008',
#  'PCT_SE_T049_009',
#  'PCT_SE_T049_010',
#  'PCT_SE_T049_011',
#  'PCT_SE_T049_012',
#  'PCT_SE_T049_013',
#  'PCT_SE_T049_014',
#  'PCT_SE_T053_006',
#  'SE_T057_001',
#  'SE_T058_002',
#  'SE_T058_003',
#  'SE_T058_004',
#  'SE_T058_005',
#  'SE_T058_006',
#  'SE_T058_007',
#  'SE_T058_008',
#  'SE_T058_009',
#  'SE_T058_010',
#  'SE_T083_001',
#  'SE_T157_001',
#  'SE_T098_001',
#  'SE_T101_001',
#  'PCT_SE_T103_002',
#  'PCT_SE_T103_003',
#  'PCT_SE_T103_004',
#  'PCT_SE_T103_005',
#  'PCT_SE_T103_006',
#  'PCT_SE_T113_002',
#  'PCT_SE_T113_011',
#  'SE_T114_001',
#  'PCT_SE_T114_002',
#  'PCT_SE_T114_003',
#  'PCT_SE_T130_002',
#  'PCT_SE_T130_003',
#  'PCT_SE_T130_004',
#  'PCT_SE_T130_005',
#  'PCT_SE_T130_006',
#  'PCT_SE_T133_002',
#  'PCT_SE_T133_003',
#  'PCT_SE_T133_004',
#  'PCT_SE_T133_005',
#  'PCT_SE_T139_002',
#  'PCT_SE_T139_034',
#  'PCT_SE_T139_067',
#  'PCT_SE_T139_085',
#  'PCT_SE_T139_090',
#  'SE_T145_001',
#  'PCT_SE_T145_002',
#  'PCT_SE_T145_003',
#  'PCT_SE_T145_004',
#  'PCT_SE_T145_005',
#  'close99',
#  'close00',
#  'close01',
#  'close02',
#  'close03',
#  'close04',
#  'close05',
#  'close06',
#  'close07',
#  'close08',
#  'close09',
#  'close10',
#  'close11',
#  'close12',
#  'close13',
#  'close14',
#  'close15',
#  'close16',
#  'close_rate99',
#  'close_rate00',
#  'close_rate01',
#  'close_rate02',
#  'close_rate03',
#  'close_rate04',
#  'close_rate05',
#  'close_rate06',
#  'close_rate07',
#  'close_rate08',
#  'close_rate09',
#  'close_rate10',
#  'close_rate11',
#  'close_rate12',
#  'close_rate13',
#  'close_rate14',
#  'close_rate15',
#  'close_rate16',
#  'POPTOT_S16',
#  'POP517_S16',
#  'CHILDPOV_S16',
#  'TRUE_CHARTER',
#  'TITLEI',
#  'FTE',
#  'YEAR_OPENED',
#  'YEAR_CLOSED',
#  'SEARCH16',
#  'TOTETH',
#  'PCTETH',
#  'AGE',
#  'PCTFRL',
#  'PLACE',
#  'STR',
#  'WEBTEXT_METHOD',
#  'ess_strength_y',
#  'prog_strength_y',
#  'PROG_COUNT',
#  'RIT_COUNT',
#  'ESS_COUNT',
#  'ESS_STR',
#  'PROG_STR',
#  'RIT_STR',
#  'TOT_LEPENR_M',
#  'TOT_LEPENR_F',
#  'TOT_LEPPROGENR_M',
#  'TOT_LEPPROGENR_F',
#  'TOT_IDEAENR_M',
#  'TOT_IDEAENR_F',
#  'SCH_IDEAENR_LEP_M',
#  'SCH_IDEAENR_LEP_F',
#  'TOT_504ENR_M',
#  'TOT_504ENR_F',
#  'TOT_GTENR_M',
#  'TOT_GTENR_F',
#  'SCH_CREDITRECOVERY_IND',
#  'SCH_CREDITRECOVERYENR',
#  'SCH_SSCLASSES_IND',
#  'SCH_APENR_IND',
#  'SCH_APCOURSES',
#  'TOT_APENR_M',
#  'TOT_APENR_F',
#  'TOT_APEXAM_ONEORMORE_M',
#  'TOT_APEXAM_ONEORMORE_F',
#  'TOT_APEXAM_NONE_M',
#  'TOT_APEXAM_NONE_F',
#  'TOT_APPASS_ONEORMORE_M',
#  'TOT_APPASS_ONEORMORE_F',
#  'TOT_APPASS_NONE_M',
#  'TOT_APPASS_NONE_F',
#  'SCH_IBENR_IND',
#  'TOT_IBENR_M',
#  'TOT_IBENR_F',
#  'TOT_SATACT_M',
#  'TOT_SATACT_F',
#  'SCH_CORPINSTANCES_IND',
#  'SCH_PSDISC_CORP_HI_M',
#  'SCH_PSDISC_CORP_HI_F',
#  'SCH_PSDISC_CORP_AM_M',
#  'SCH_PSDISC_CORP_AM_F',
#  'SCH_PSDISC_CORP_AS_M',
#  'SCH_PSDISC_CORP_AS_F',
#  'SCH_PSDISC_CORP_HP_M',
#  'SCH_PSDISC_CORP_HP_F',
#  'SCH_PSDISC_CORP_BL_M',
#  'SCH_PSDISC_CORP_BL_F',
#  'SCH_PSDISC_CORP_WH_M',
#  'SCH_PSDISC_CORP_WH_F',
#  'SCH_PSDISC_CORP_TR_M',
#  'SCH_PSDISC_CORP_TR_F',
#  'TOT_PSDISC_CORP_M',
#  'TOT_PSDISC_CORP_F',
#  'SCH_PSDISC_CORP_LEP_M',
#  'SCH_PSDISC_CORP_LEP_F',
#  'SCH_PSDISC_CORP_IDEA_M',
#  'SCH_PSDISC_CORP_IDEA_F',
#  'SCH_PSCORPINSTANCES_ALL',
#  'TOT_PSDISC_SINGOOS_M',
#  'TOT_PSDISC_SINGOOS_F',
#  'TOT_PSDISC_MULTOOS_M',
#  'TOT_PSDISC_MULTOOS_F',
#  'SCH_PSOOSINSTANCES_ALL',
#  'SCH_PSOOSINSTANCES_IDEA',
#  'SCH_OOSINSTANCES_WODIS',
#  'SCH_OOSINSTANCES_IDEA',
#  'SCH_OOSINSTANCES_504',
#  'SCH_DAYSMISSED_HI_M',
#  'SCH_DAYSMISSED_HI_F',
#  'SCH_DAYSMISSED_AM_M',
#  'SCH_DAYSMISSED_AM_F',
#  'SCH_DAYSMISSED_AS_M',
#  'SCH_DAYSMISSED_AS_F',
#  'SCH_DAYSMISSED_HP_M',
#  'SCH_DAYSMISSED_HP_F',
#  'SCH_DAYSMISSED_BL_M',
#  'SCH_DAYSMISSED_BL_F',
#  'SCH_DAYSMISSED_WH_M',
#  'SCH_DAYSMISSED_WH_F',
#  'SCH_DAYSMISSED_TR_M',
#  'SCH_DAYSMISSED_TR_F',
#  'TOT_DAYSMISSED_M',
#  'TOT_DAYSMISSED_F',
#  'SCH_DAYSMISSED_LEP_M',
#  'SCH_DAYSMISSED_LEP_F',
#  'SCH_DAYSMISSED_504_M',
#  'SCH_DAYSMISSED_504_F',
#  'SCH_DAYSMISSED_IDEA_M',
#  'SCH_DAYSMISSED_IDEA_F',
#  'SCH_PSDISC_EXP_HI_M',
#  'SCH_PSDISC_EXP_HI_F',
#  'SCH_PSDISC_EXP_AM_M',
#  'SCH_PSDISC_EXP_AM_F',
#  'SCH_PSDISC_EXP_AS_M',
#  'SCH_PSDISC_EXP_AS_F',
#  'SCH_PSDISC_EXP_HP_M',
#  'SCH_PSDISC_EXP_HP_F',
#  'SCH_PSDISC_EXP_BL_M',
#  'SCH_PSDISC_EXP_BL_F',
#  'SCH_PSDISC_EXP_WH_M',
#  'SCH_PSDISC_EXP_WH_F',
#  'SCH_PSDISC_EXP_TR_M',
#  'SCH_PSDISC_EXP_TR_F',
#  'TOT_PSDISC_EXP_M',
#  'TOT_PSDISC_EXP_F',
#  'SCH_PSDISC_EXP_LEP_M',
#  'SCH_PSDISC_EXP_LEP_F',
#  'SCH_PSDISC_EXP_IDEA_M',
#  'SCH_PSDISC_EXP_IDEA_F',
#  'TOT_DISCWODIS_EXPWE_M',
#  'TOT_DISCWODIS_EXPWE_F',
#  'TOT_DISCWODIS_EXPWOE_M',
#  'TOT_DISCWODIS_EXPWOE_F',
#  'SCH_DISCWODIS_EXPZT_HI_M',
#  'SCH_DISCWODIS_EXPZT_HI_F',
#  'SCH_DISCWODIS_EXPZT_AM_M',
#  'SCH_DISCWODIS_EXPZT_AM_F',
#  'SCH_DISCWODIS_EXPZT_AS_M',
#  'SCH_DISCWODIS_EXPZT_AS_F',
#  'SCH_DISCWODIS_EXPZT_HP_M',
#  'SCH_DISCWODIS_EXPZT_HP_F',
#  'SCH_DISCWODIS_EXPZT_BL_M',
#  'SCH_DISCWODIS_EXPZT_BL_F',
#  'SCH_DISCWODIS_EXPZT_WH_M',
#  'SCH_DISCWODIS_EXPZT_WH_F',
#  'SCH_DISCWODIS_EXPZT_TR_M',
#  'SCH_DISCWODIS_EXPZT_TR_F',
#  'TOT_DISCWODIS_EXPZT_M',
#  'TOT_DISCWODIS_EXPZT_F',
#  'SCH_DISCWODIS_EXPZT_LEP_M',
#  'SCH_DISCWODIS_EXPZT_LEP_F',
#  'TOT_DISCWDIS_EXPWE_IDEA_M',
#  'TOT_DISCWDIS_EXPWE_IDEA_F',
#  'TOT_DISCWDIS_EXPWOE_IDEA_M',
#  'TOT_DISCWDIS_EXPWOE_IDEA_F',
#  'SCH_DISCWDIS_EXPZT_IDEA_HI_M',
#  'SCH_DISCWDIS_EXPZT_IDEA_HI_F',
#  'SCH_DISCWDIS_EXPZT_IDEA_AM_M',
#  'SCH_DISCWDIS_EXPZT_IDEA_AM_F',
#  'SCH_DISCWDIS_EXPZT_IDEA_AS_M',
#  'SCH_DISCWDIS_EXPZT_IDEA_AS_F',
#  'SCH_DISCWDIS_EXPZT_IDEA_HP_M',
#  'SCH_DISCWDIS_EXPZT_IDEA_HP_F',
#  'SCH_DISCWDIS_EXPZT_IDEA_BL_M',
#  'SCH_DISCWDIS_EXPZT_IDEA_BL_F',
#  'SCH_DISCWDIS_EXPZT_IDEA_WH_M',
#  'SCH_DISCWDIS_EXPZT_IDEA_WH_F',
#  'SCH_DISCWDIS_EXPZT_IDEA_TR_M',
#  'SCH_DISCWDIS_EXPZT_IDEA_TR_F',
#  'TOT_DISCWDIS_EXPZT_IDEA_M',
#  'TOT_DISCWDIS_EXPZT_IDEA_F',
#  'SCH_DISCWDIS_EXPZT_LEP_M',
#  'SCH_DISCWDIS_EXPZT_LEP_F',
#  'SCH_DISCWDIS_EXPZT_504_M',
#  'SCH_DISCWDIS_EXPZT_504_F',
#  'TOT_DISCWODIS_TFRALT_M',
#  'TOT_DISCWODIS_TFRALT_F',
#  'TOT_DISCWDIS_TFRALT_IDEA_M',
#  'TOT_DISCWDIS_TFRALT_IDEA_F',
#  'TOT_DISCWODIS_REF_M',
#  'TOT_DISCWODIS_REF_F',
#  'TOT_DISCWDIS_REF_IDEA_M',
#  'TOT_DISCWDIS_REF_IDEA_F',
#  'TOT_DISCWODIS_ARR_M',
#  'TOT_DISCWODIS_ARR_F',
#  'TOT_DISCWDIS_ARR_IDEA_M',
#  'TOT_DISCWDIS_ARR_IDEA_F',
#  'SCH_FIREARM_IND',
#  'SCH_HOMICIDE_IND',
#  'SCH_OFFENSE_RAPE',
#  'SCH_OFFENSE_BATT',
#  'SCH_OFFENSE_ROBWW',
#  'SCH_OFFENSE_ROBWX',
#  'SCH_OFFENSE_ROBWOW',
#  'SCH_OFFENSE_ATTWW',
#  'SCH_OFFENSE_ATTWX',
#  'SCH_OFFENSE_ATTWOW',
#  'SCH_OFFENSE_THRWW',
#  'SCH_OFFENSE_THRWX',
#  'SCH_OFFENSE_THRWOW',
#  'SCH_OFFENSE_POSSWX',
#  'TOT_RS_NONIDEA_MECH_M',
#  'TOT_RS_NONIDEA_MECH_F',
#  'TOT_RS_NONIDEA_PHYS_M',
#  'TOT_RS_NONIDEA_PHYS_F',
#  'TOT_RS_NONIDEA_SECL_M',
#  'TOT_RS_NONIDEA_SECL_F',
#  'TOT_RS_IDEA_MECH_M',
#  'TOT_RS_IDEA_MECH_F',
#  'TOT_RS_IDEA_PHYS_M',
#  'TOT_RS_IDEA_PHYS_F',
#  'TOT_RS_IDEA_SECL_M',
#  'TOT_RS_IDEA_SECL_F',
#  'SCH_RSINSTANCES_MECH_WODIS',
#  'SCH_RSINSTANCES_MECH_IDEA',
#  'SCH_RSINSTANCES_MECH_504',
#  'SCH_RSINSTANCES_PHYS_WODIS',
#  'SCH_RSINSTANCES_PHYS_IDEA',
#  'SCH_RSINSTANCES_PHYS_504',
#  'SCH_RSINSTANCES_SECL_WODIS',
#  'SCH_RSINSTANCES_SECL_IDEA',
#  'SCH_RSINSTANCES_SECL_504',
#  'SCH_HBALLEGATIONS_SEX',
#  'SCH_HBALLEGATIONS_RAC',
#  'SCH_HBALLEGATIONS_DIS',
#  'SCH_HBALLEGATIONS_ORI',
#  'SCH_HBALLEGATIONS_REL',
#  'TOT_HBREPORTED_SEX_M',
#  'TOT_HBREPORTED_SEX_F',
#  'TOT_HBREPORTED_RAC_M',
#  'TOT_HBREPORTED_RAC_F',
#  'TOT_HBREPORTED_DIS_M',
#  'TOT_HBREPORTED_DIS_F',
#  'TOT_ABSENT_M',
#  'TOT_ABSENT_F',
#  'SCH_RET_KG_IND',
#  'SCH_RET_G01_IND',
#  'SCH_RET_G02_IND',
#  'SCH_RET_G03_IND',
#  'SCH_RET_G04_IND',
#  'SCH_RET_G05_IND',
#  'SCH_RET_G06_IND',
#  'SCH_RET_G07_IND',
#  'SCH_RET_G08_IND',
#  'SCH_RET_G09_IND',
#  'SCH_RET_G10_IND',
#  'SCH_RET_G11_IND',
#  'SCH_RET_G12_IND',
#  'TOT_RET_KG_M',
#  'TOT_RET_KG_F',
#  'TOT_RET_G01_M',
#  'TOT_RET_G01_F',
#  'TOT_RET_G02_M',
#  'TOT_RET_G02_F',
#  'TOT_RET_G03_M',
#  'TOT_RET_G03_F',
#  'TOT_RET_G04_M',
#  'TOT_RET_G04_F',
#  'TOT_RET_G05_M',
#  'TOT_RET_G05_F',
#  'TOT_RET_G06_M',
#  'TOT_RET_G06_F',
#  'TOT_RET_G07_M',
#  'TOT_RET_G07_F',
#  'TOT_RET_G08_M',
#  'TOT_RET_G08_F',
#  'TOT_RET_G09_M',
#  'TOT_RET_G09_F',
#  'TOT_RET_G10_M',
#  'TOT_RET_G10_F',
#  'TOT_RET_G11_M',
#  'TOT_RET_G11_F',
#  'TOT_RET_G12_M',
#  'TOT_RET_G12_F',
#  'SCH_SSATHLETICS_IND',
#  'TOT_SSPART',
#  'SCH_FTE_TEACH_WOFED',
#  'SCH_NPE_WOFED',
#  'SCH_FTE_AID_WOFED',
#  'SCH_FTE_SUP_WOFED',
#  'SCH_FTE_ADM_WOFED',
#  'SCH_FTE_AID_WFED',
#  'SCH_FTE_SUP_WFED',
#  'SCH_FTE_ADM_WFED',
#  'SCH_FTETEACH_TOT',
#  'SCH_FTETEACH_CERT',
#  'SCH_FTETEACH_NOTCERT',
#  'SCH_FTETEACH_FY',
#  'SCH_FTETEACH_SY',
#  'SCH_TEACHERS_CURR_TOT',
#  'SCH_TEACHERS_PREV_TOT',
#  'SCH_FTECOUNSELORS',
#  'SCH_FTETEACH_ABSENT',
#  'SCH_FTESECURITY_LEO',
#  'SCH_FTESECURITY_GUA',
#  'SCH_FTESERVICES_NUR',
#  'SCH_FTESERVICES_PSY',
#  'SCH_FTESERVICES_SOC',
#  'DISCIPLINE_COUNT',
#  'INQUIRY_COUNT',
#  'DISC_STR',
#  'INQU_STR',
#  'PCTBA_SD',
#  'PCTETH_SD',
#  'ADDRESS1516',
#  'NUMPAGES',
#  'NUMWORDS',
#  'DISC_RATIO',
#  'INQ_RATIO',
#  'ESS_RATIO',
#  'PROG_RATIO',
#  'INQ_STR',
#  'WEBTEXT',
#  'CMO_WEBTEXT',
#  'UNSCRAPED',
#  'INQUIRY_STR',
#  'DISCIPLINE_STR',
#  'ESS_VALID_COUNT',
#  'ESS_VALID_STR',
#  'PROG_VALID_COUNT',
#  'PROG_VALID_STR',
#  'RIT_VALID_COUNT',
#  'RIT_VALID_STR',
#  'INQUIRY_RATIO',
#  'DISCIPLINE_RATIO',
#  'ESS_VALID_RATIO',
#  'PROG_VALID_RATIO',
#  'RIT_VALID_RATIO']

# %%
# Keep only rows that are missing WEBTEXT (scrape failed):
notext1 = charterdf['WEBTEXT'].isnull() # Store rows where WEBTEXT missing
notext2 = charterdf[charterdf["WEBTEXT"].apply(len) == 0] # Store rows where NO WEBTEXT (0 pages) was gathered

# To prepare for parsing deeper into WEBTEXT to look for null results, now exclude schools with no WEBTEXT
charterdf = charterdf[charterdf["WEBTEXT"].apply(len) > 0] # Keep only rows with some WEBTEXT (at least one page)
charterdf = charterdf.dropna(subset = ['WEBTEXT']) # drop if WEBTEXT missing

notext3 = charterdf[charterdf["WEBTEXT"].apply(lambda school: len(school[0][3])) == 0] # Store rows where first scraped page is empty
notext4 = charterdf[charterdf["WEBTEXT"].apply(lambda school: sum([len(page[3]) for page in school])) == 0] # Store rows where all pages are empty

# %%
print("# rows, #cols: ", notext1.shape)
print("# rows, #cols: ", notext2.shape)
print("# rows, #cols: ", notext3.shape)
print("# rows, #cols: ", notext4.shape)
# Out:
# # rows, #cols:  (7137,)
# # rows, #cols:  (275, 702)
# # rows, #cols:  (442, 702)
# # rows, #cols:  (399, 702)

# %%
# Now concatenate these stored rows into one DF:
hasurl_df = pd.concat([notext1, notext2, notext3, notext4])
print(hasurl_df.shape)
# Out:
# (8253, 703)
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/api.py:107: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   result = result.union(other)

# %%
# Keep only those columns useful for URL collection:
hasurl_df = hasurl_df[["SEARCH16", "URL", "NCESSCH", "SCHNAM16", "ADDRESS16", "SY_STATUS16", "SY_STATUS15", "LEVEL", "STABR", "WEBSITE", "YEAR_CLOSED", "SCH_NAME", "YEAR_OPENED"]]

# %%
print("# duplicates by NCESSCH: ", sum(hasurl_df.duplicated(subset='NCESSCH', keep='first')))

# Eliminate duplicates in pubschool data:
print("Removing duplicates...")
hasurl_df = hasurl_df.drop_duplicates(subset="NCESSCH", keep='first')

print("NEW # duplicates by NCESSCH: ", sum(hasurl_df.duplicated(subset='NCESSCH', keep='first')))
# Out:
# # duplicates by NCESSCH:  7535
# Removing duplicates...
# NEW # duplicates by NCESSCH:  0

# %%
print("#rows, #cols WITH empty by NCESSCH: ", hasurl_df.shape)
hasurl_df.dropna(subset=["NCESSCH"], inplace=True)
print("#rows, #cols WITHOUT empty by NCESSCH: ", hasurl_df.shape)
# Out:
# #rows, #cols WITH empty by NCESSCH:  (717, 13)
# #rows, #cols WITHOUT empty by NCESSCH:  (717, 13)

# %%
list(hasurl_df)
# Out:
# ['SEARCH16',
#  'URL',
#  'NCESSCH',
#  'SCHNAM16',
#  'ADDRESS16',
#  'SY_STATUS16',
#  'SY_STATUS15',
#  'LEVEL',
#  'STABR',
#  'WEBSITE',
#  'YEAR_CLOSED',
#  'SCH_NAME',
#  'YEAR_OPENED']

# %%
hasurl_df
# Out:
#                                                 SEARCH16  \
# 1      AYAPRUN ELITNAURVIK  1010 Fourth Avenue , Beth...
# 5      FAMILY PARTNERSHIP CHARTER SCHOOL  401 E Firew...
# 12     RILKE SCHULE CHARTER SCHOOL  650 W Internation...
# 16     AURORA BOREALIS CHARTER SCHOOL  705 Frontage R...
# 28     ANVIL CITY SCIENCE ACADEMY  Mile 3.5 Nome-Tell...
# 32     EFFIE KOKRINE CHARTER SCHOOL  601 Loftus Road ...
# 143    KINGMAN ACADEMY OF LEARNING - HIGH SCHOOL  342...
# 381    CANYON VIEW PREP ACADEMY  9030 E Florentine Ro...
# 443    PARADISE EDUCATION CENTER  15533 W. Paradise L...
# 444    PARADISE HONORS HIGH SCHOOL  12775 N. 175th Av...
# 569    COMPASS HIGH SCHOOL  8250 E.  22nd St. 128 , T...
# 570    CROWN POINT HIGH SCHOOL  3830 North 67th Avenu...
# 724    BRADLEY ACADEMY OF EXCELLENCE  200 North Dysar...
# 739    PINNACLE ONLINE HIGH SCHOOL  4700 S. McClintoc...
# 785    INTEGRITY EDUCATION CENTRE  515 E. Continental...
# 905    LEADING EDGE ACADEMY SAN TAN  7377 W. Hunt Hwy...
# 943    CAMINO MONTESSORI  44301 West Maricopa/Casa Gr...
# 1114   OZARK MONTESSORI ACADEMY SPRINGDALE  301 S HOL...
# 1121   PEA RIDGE MANUFACTURING & BUSINESS ACADEMY  78...
# 1151   SCALE LEADERSHIP ACADEMY  32248 Crown Valley R...
# 1185   MARIA MONTESSORI CHARTER ACADEMY  1850 Wildcat...
# 1269   SMYTHE ACADEMY OF ARTS AND SCIENCES  2781 N.ga...
# 1330   TAYLION HIGH DESERT ACADEMY/ADELANTO  11336 Ba...
# 1346   GOALS ACADEMY  412 W. Carl Karcher Way , Anahe...
# 1529   IPAKANNI EARLY COLLEGE CHARTER  1459 Downer St...
# 1556   SIERRA CHARTER  1931 N. Fine Ave. , Fresno CA ...
# 1620   KINETIC ACADEMY  721 Utica Ave. , Huntington B...
# 1636   JULIAN CHARTER  1704 Cape Horn , Julian CA 920...
# 1660   BARONA INDIAN CHARTER  1095 Barona Rd. , Lakes...
# 1766   HAYNES CHARTER FOR ENRICHED STUDIES  6624 Lock...
# ...                                                  ...
# 8909   MEMPHIS ACADEMY OF HEALTH SCIENCES HIGH SCHOOL...
# 8920   KIPP MEMPHIS COLLEGIATE HIGH SCHOOL  2110 Howe...
# 8923   KIPP MEMPHIS COLLEGIATE ELEMENTARY  230 Henry ...
# 8924   KIPP MEMPHIS MIDDLE ACADEMY  2110 Howell , Mem...
# 8928   DUBOIS HIGH SCHOOL OF ARTS  TECHNOLOGY  817 Br...
# 8932   DUBOIS ELEMENTARY SCHOOL OF ENTREPRENEURSHIP  ...
# 8934   DUBOIS ELEMENTARY SCHOOL OF ARTS  TECHNOLOGY  ...
# 8937   DUBOIS MIDDLE SCHOOL OF ARTS  TECHNOLOGY  817 ...
# 8992   NEW VISION ACADEMY  297 Plus Park BL , Nashvil...
# 8999   LEAD PREP SOUTHEAST  531 Metroplex DR , Nashvi...
# 9073   ACCELERATED LEARNING CENTER  4129 GREENWOOD DR...
# 9074   GCCLR INSTITUTE OF TECHNOLOGY  2203 BALDWIN BL...
# 9160                                                 NaN
# 9249   TEXAS EMPOWERMENT ACADEMY  3613 BLUESTEIN DR ,...
# 9250   TEXAS EMPOWERMENT ACADEMY EL  6414 N HAMPTON ,...
# 9326   HERITAGE ACADEMY OF WINDCREST  8750 FOURWINDS ...
# 9358   ACADEMY OF DALLAS  1030 OAK PARK DR , DALLAS T...
# 9777   NEW HORIZONS  850 FM 574 W , GOLDTHWAITE TX 76...
# 9877   BROOKS ACADEMY OF SCIENCE AND ENGINEERING  380...
# 9879   BROOKS INTERNATIONAL STUDIES ACADEMY  134 E LA...
# 9880   BROOKS ACADEMY OAKS  6070 BABCOCK RD , SAN ANT...
# 9966   SCHOOL OF SCIENCE AND TECHNOLOGY DISCOVERY  57...
# 10014                                                NaN
# 10100  THE LONE STAR LANGUAGE ACADEMY  720 W LOOKOUT ...
# 10127     BURNET/ECU  5501 AVE S , GALVESTON TX 77550.0
# 10233  ODYSSEY CHARTER SCHOOL  738 E QUALITY DR , Ame...
# 10246  SUCCESS DSU  225 South 700 East Technology Bui...
# 10294  EXCELSIOR ACADEMY  124 E ERDA WAY , ERDA UT 84...
# 10307                                                NaN
# 10530    CORE4  5000 S 116th St , Greenfield WI 53228.0
#
#                                                      URL       NCESSCH  \
# 1      https://education.alaska.gov/DOE_Rolodex/Schoo...  2.000010e+10
# 5      https://education.alaska.gov/DOE_Rolodex/Schoo...  2.001800e+10
# 12     https://education.alaska.gov/DOE_Rolodex/Schoo...  2.001800e+10
# 16     https://education.alaska.gov/DOE_Rolodex/Schoo...  2.003900e+10
# 28              http://nome.nosd.schoolaccess.net/~acsa/  2.005700e+10
# 32                          http://ekc.k12northstar.org/  2.006000e+10
# 143                      http://kaolaz.org/calendar.html  4.000740e+10
# 381                       http://www.canyonviewprep.org/  4.002090e+10
# 443                           http://www.pecschools.org/  4.002410e+10
# 444                               http://pecschools.org/  4.002410e+10
# 569                    http://www.compasshighschool.com/  4.003300e+10
# 570                        https://www.crownpoinths.net/  4.003320e+10
# 724                           http://bradleycreemos.org/  4.006090e+10
# 739             http://www.pinnacleonlinehighschool.com/  4.006210e+10
# 785             http://www.integrityeducationcentre.com/  4.006500e+10
# 905           http://www.leadingedgeacademy.com/san-tan/  4.008450e+10
# 943                         http://caminomontessori.com/  4.008830e+10
# 1114                                http://ozarkcca.org/  5.004150e+10
# 1121                        https://www.pearidgemba.com/  5.030300e+10
# 1151                        http://www.scaleacademy.org/  6.000011e+10
# 1185                           http://www.mmcharter.org/  6.000131e+10
# 1269           https://smythek6-trusd_ca.schoolloop.com/  6.013320e+10
# 1330                   http://www.taylionhighdesert.com/  6.017101e+10
# 1346                             http://goalsacademy.us/  6.026101e+10
# 1529                            http://www.ipakanni.com/  6.137101e+10
# 1556                       http://www.sierracharter.org/  6.145501e+10
# 1620                      http://www.kineticacademy.org/  6.180301e+10
# 1636                 http://www.juliancharterschool.org/  6.191401e+10
# 1660           http://www.baronaindiancharterschool.com/  6.207901e+10
# 1766                           http://haynescharter.com/  6.227101e+10
# ...                                                  ...           ...
# 8909   http://www.mahsmiddleandhigh.com/apps/pages/in...  4.700148e+11
# 8920   http://www.kippmemphis.org/apps/pages/index.js...  4.700148e+11
# 8923   http://www.kippmemphis.org/apps/pages/index.js...  4.700148e+11
# 8924   http://www.kippmemphis.org/apps/pages/index.js...  4.700148e+11
# 8928   http://www.duboisartsandtech.org/apps/pages/in...  4.700148e+11
# 8932                   http://www.duboisartsandtech.org/  4.700148e+11
# 8934   http://www.duboisartsandtech.org/apps/pages/in...  4.700148e+11
# 8937   http://www.duboisartsandtech.org/apps/pages/in...  4.700148e+11
# 8992                  http://www.newvisionacademytn.org/  4.703180e+11
# 8999                       http://leadprepsoutheast.org/  4.703180e+11
# 9073                       https://ggcs.cyberschool.com/  4.800025e+11
# 9074                               http://www.gcclr.org/  4.800025e+11
# 9160                         http://higgscarterking.org/  4.800050e+11
# 9249                    http://www.texasempowerment.org/  4.800066e+11
# 9250                    http://www.texasempowerment.org/  4.800066e+11
# 9326                        http://www.shekinah-edu.com/  4.800080e+11
# 9358   http://www.academyofdallas.com/pages/Academy_o...  4.800090e+11
# 9777                      http://www.newhorizonsinc.com/  4.800235e+11
# 9877                      http://base.brooksacademy.org/  4.800268e+11
# 9879                           http://brooksacademy.org/  4.800268e+11
# 9880                      http://oaks.brooksacademy.org/  4.800268e+11
# 9966                       https://www.sstdiscovery.org/  4.801400e+11
# 10014                       http://mha.arrowacademy.org/  4.801416e+11
# 10100                             http://lonestartx.org/  4.801452e+11
# 10127  http://www.gisd.org/education/components/layou...  4.820280e+11
# 10233                         http://odysseycharter.net/  4.900021e+11
# 10246                           http://dixiesuccess.org/  4.900037e+11
# 10294                  http://www.excelsior-academy.org/  4.900136e+11
# 10307                              http://www.utmcs.org/  4.900149e+11
# 10530                    http://hce.whitnallschools.com/  5.506000e+11
#
#                                              SCHNAM16  \
# 1                                 AYAPRUN ELITNAURVIK
# 5                   FAMILY PARTNERSHIP CHARTER SCHOOL
# 12                        RILKE SCHULE CHARTER SCHOOL
# 16                     AURORA BOREALIS CHARTER SCHOOL
# 28                         ANVIL CITY SCIENCE ACADEMY
# 32                       EFFIE KOKRINE CHARTER SCHOOL
# 143         KINGMAN ACADEMY OF LEARNING - HIGH SCHOOL
# 381                          CANYON VIEW PREP ACADEMY
# 443                         PARADISE EDUCATION CENTER
# 444                       PARADISE HONORS HIGH SCHOOL
# 569                               COMPASS HIGH SCHOOL
# 570                           CROWN POINT HIGH SCHOOL
# 724                     BRADLEY ACADEMY OF EXCELLENCE
# 739                       PINNACLE ONLINE HIGH SCHOOL
# 785                        INTEGRITY EDUCATION CENTRE
# 905                      LEADING EDGE ACADEMY SAN TAN
# 943                                 CAMINO MONTESSORI
# 1114              OZARK MONTESSORI ACADEMY SPRINGDALE
# 1121       PEA RIDGE MANUFACTURING & BUSINESS ACADEMY
# 1151                         SCALE LEADERSHIP ACADEMY
# 1185                 MARIA MONTESSORI CHARTER ACADEMY
# 1269              SMYTHE ACADEMY OF ARTS AND SCIENCES
# 1330             TAYLION HIGH DESERT ACADEMY/ADELANTO
# 1346                                    GOALS ACADEMY
# 1529                   IPAKANNI EARLY COLLEGE CHARTER
# 1556                                   SIERRA CHARTER
# 1620                                  KINETIC ACADEMY
# 1636                                   JULIAN CHARTER
# 1660                            BARONA INDIAN CHARTER
# 1766              HAYNES CHARTER FOR ENRICHED STUDIES
# ...                                               ...
# 8909   MEMPHIS ACADEMY OF HEALTH SCIENCES HIGH SCHOOL
# 8920              KIPP MEMPHIS COLLEGIATE HIGH SCHOOL
# 8923               KIPP MEMPHIS COLLEGIATE ELEMENTARY
# 8924                      KIPP MEMPHIS MIDDLE ACADEMY
# 8928           DUBOIS HIGH SCHOOL OF ARTS  TECHNOLOGY
# 8932     DUBOIS ELEMENTARY SCHOOL OF ENTREPRENEURSHIP
# 8934     DUBOIS ELEMENTARY SCHOOL OF ARTS  TECHNOLOGY
# 8937         DUBOIS MIDDLE SCHOOL OF ARTS  TECHNOLOGY
# 8992                               NEW VISION ACADEMY
# 8999                              LEAD PREP SOUTHEAST
# 9073                      ACCELERATED LEARNING CENTER
# 9074                    GCCLR INSTITUTE OF TECHNOLOGY
# 9160                                              NaN
# 9249                        TEXAS EMPOWERMENT ACADEMY
# 9250                     TEXAS EMPOWERMENT ACADEMY EL
# 9326                    HERITAGE ACADEMY OF WINDCREST
# 9358                                ACADEMY OF DALLAS
# 9777                                     NEW HORIZONS
# 9877        BROOKS ACADEMY OF SCIENCE AND ENGINEERING
# 9879             BROOKS INTERNATIONAL STUDIES ACADEMY
# 9880                              BROOKS ACADEMY OAKS
# 9966       SCHOOL OF SCIENCE AND TECHNOLOGY DISCOVERY
# 10014                                             NaN
# 10100                  THE LONE STAR LANGUAGE ACADEMY
# 10127                                      BURNET/ECU
# 10233                          ODYSSEY CHARTER SCHOOL
# 10246                                     SUCCESS DSU
# 10294                               EXCELSIOR ACADEMY
# 10307                                             NaN
# 10530                                           CORE4
#
#                                                ADDRESS16  SY_STATUS16  \
# 1                1010 Fourth Avenue , Bethel AK 99559.0           1.0
# 5       401 E Fireweed Lane Suite 100 , Anchorage AK ...          1.0
# 12      650 W International Airport Rd , Anchorage AK...          1.0
# 16           705 Frontage Rd Suite A , Kenai AK 99611.0           1.0
# 28       Mile 3.5 Nome-Teller Highway , Nome AK 99762.0           1.0
# 32               601 Loftus Road , Fairbanks AK 99709.0           1.0
# 143           3420 N. Burbank Ave. , Kingman AZ 86409.0           1.0
# 381     9030 E Florentine Road , Prescott Valley AZ 8...          1.0
# 443         15533 W. Paradise Ln. , Surprise AZ 85374.0           1.0
# 444         12775 N. 175th Avenue , Surprise AZ 85374.0           1.0
# 569           8250 E.  22nd St. 128 , Tucson AZ 85710.0           1.0
# 570         3830 North 67th Avenue , Phoenix AZ 85033.0           1.0
# 724         200 North Dysart Road , Avondale AZ 85323.0           1.0
# 739     4700 S. McClintock Dr. Unit 140 , Tempe AZ 85...          1.0
# 785           515 E. Continental Dr. , Tempe AZ 85281.0           1.0
# 905          7377 W. Hunt Hwy. , Queen Creek AZ 85142.0           1.0
# 943     44301 West Maricopa/Casa Grand , Maricopa AZ ...          1.0
# 1114           301 S HOLCOMB ST , SPRINGDALE AR 72764.0           1.0
# 1121         781 WEST PICKENS RD , PEA RIDGE AR 72751.0           1.0
# 1151       32248 Crown Valley Rd. , Acton CA CA 93510.0           1.0
# 1185            1850 Wildcat Blvd. , Rocklin CA 95765.0           1.0
# 1269          2781 N.gate Blvd. , Sacramento CA 95833.0           1.0
# 1330       11336 Bartlett Ave. #9 , Adelanto CA 92301.0           1.0
# 1346       412 W. Carl Karcher Way , Anaheim CA 92801.0           1.0
# 1529              1459 Downer St. , Oroville CA 95966.0           1.0
# 1556              1931 N. Fine Ave. , Fresno CA 93727.0           1.0
# 1620       721 Utica Ave. , Huntington Beach CA 92648.0           3.0
# 1636                 1704 Cape Horn , Julian CA 92036.0           1.0
# 1660              1095 Barona Rd. , Lakeside CA 92040.0           1.0
# 1766         6624 Lockhurst Dr. , West Hills CA 91307.0           1.0
# ...                                                  ...          ...
# 8909         3925 Chelsea Extended , Memphis TN 38107.0           1.0
# 8920                2110 Howell AV , Memphis TN 38108.0           1.0
# 8923                  230 Henry AV , Memphis TN 38107.0           1.0
# 8924                   2110 Howell , Memphis TN 38108.0           1.0
# 8928               817 Brownlee RD , Memphis TN 38116.0           1.0
# 8932         111 S. Highland # 189 , Memphis TN 38111.0           1.0
# 8934               817 Brownlee RD , Memphis TN 38116.0           1.0
# 8937               817 Brownlee RD , Memphis TN 38116.0           1.0
# 8992            297 Plus Park BL , Nashville TN 37217.0           1.0
# 8999            531 Metroplex DR , Nashville TN 37211.0           1.0
# 9073      4129 GREENWOOD DR , CORPUS CHRISTI TX 78416.0           1.0
# 9074      2203 BALDWIN BLVD , CORPUS CHRISTI TX 78405.0           6.0
# 9160                                                 NaN          NaN
# 9249              3613 BLUESTEIN DR , AUSTIN TX 78721.0           1.0
# 9250                 6414 N HAMPTON , AUSTIN TX 78723.0           1.0
# 9326           8750 FOURWINDS DR , WINDCREST TX 78239.0           1.0
# 9358               1030 OAK PARK DR , DALLAS TX 75232.0           1.0
# 9777              850 FM 574 W , GOLDTHWAITE TX 76844.0           1.0
# 9877            3803 LYSTER RD , SAN ANTONIO TX 78235.0           1.0
# 9879          134 E LAMBERT ST , SAN ANTONIO TX 78204.0           1.0
# 9880           6070 BABCOCK RD , SAN ANTONIO TX 78240.0           3.0
# 9966           5707 BANDERA RD , LEON VALLEY TX 78238.0           1.0
# 10014                                                NaN          NaN
# 10100          720 W LOOKOUT DR , RICHARDSON TX 75080.0           7.0
# 10127                 5501 AVE S , GALVESTON TX 77550.0           1.0
# 10233       738 E QUALITY DR , American Fork UT 84003.0           1.0
# 10246   225 South 700 East Technology Building , ST G...          1.0
# 10294                  124 E ERDA WAY , ERDA UT 84074.0           1.0
# 10307                                                NaN          NaN
# 10530           5000 S 116th St , Greenfield WI 53228.0           1.0
#
#        SY_STATUS15 LEVEL STABR  \
# 1              1.0     1    AK
# 5              1.0     4    AK
# 12             1.0     1    AK
# 16             1.0     1    AK
# 28             1.0     2    AK
# 32             1.0     3    AK
# 143            1.0     3    AZ
# 381            1.0     3    AZ
# 443            1.0     1    AZ
# 444            1.0     3    AZ
# 569            1.0     3    AZ
# 570            1.0     3    AZ
# 724            1.0     1    AZ
# 739            1.0     4    AZ
# 785            1.0     4    AZ
# 905            1.0     4    AZ
# 943            1.0     1    AZ
# 1114           3.0     1    AR
# 1121           1.0     3    AR
# 1151           1.0     4    CA
# 1185           1.0     1    CA
# 1269           1.0     1    CA
# 1330           1.0     4    CA
# 1346           3.0     1    CA
# 1529           1.0     4    CA
# 1556           1.0     4    CA
# 1620           NaN   NaN   NaN
# 1636           1.0     4    CA
# 1660           1.0     1    CA
# 1766           1.0     1    CA
# ...            ...   ...   ...
# 8909           1.0     3    TN
# 8920           1.0     3    TN
# 8923           1.0     1    TN
# 8924           1.0     2    TN
# 8928           1.0     3    TN
# 8932           1.0     1    TN
# 8934           1.0     1    TN
# 8937           1.0     2    TN
# 8992           1.0     2    TN
# 8999           1.0     2    TN
# 9073           1.0     1    TX
# 9074           1.0     4    TX
# 9160           2.0     N    TX
# 9249           1.0     2    TX
# 9250           1.0     1    TX
# 9326           1.0     1    TX
# 9358           1.0     1    TX
# 9777           1.0     4    TX
# 9877           1.0     4    TX
# 9879           1.0     1    TX
# 9880           NaN   NaN   NaN
# 9966           1.0     1    TX
# 10014          2.0     N    TX
# 10100          7.0     N    TX
# 10127          1.0     1    TX
# 10233          1.0     1    UT
# 10246          1.0     3    UT
# 10294          1.0     1    UT
# 10307          1.0     N    UT
# 10530          1.0     1    WI
#
#                                                  WEBSITE  YEAR_CLOSED  \
# 1                              http://www.lksd.org/lksd/          NaN
# 5      http://www.asdk12.org/aboutschools/fpcs/school...          NaN
# 12     http://www.asdk12.org/aboutschools/rilkeschule...          NaN
# 16                           http://www.kpbsd.k12.ak.us/          NaN
# 28              http://nome.nosd.schoolaccess.net/~acsa/          NaN
# 32                           http://www.k12northstar.org          NaN
# 143                                http://www.kaolaz.org          NaN
# 381                                   canyonviewprep.org          NaN
# 443                                  paradiseschools.org          NaN
# 444                       http://www.paradiseschools.org          NaN
# 569                     http://www.compasshighschool.com          NaN
# 570                                                  NaN          NaN
# 724                                                  NaN          NaN
# 739                                                  NaN          NaN
# 785                     www.integrityeducationcentre.org          NaN
# 905                           www.leadingedgeacademy.com          NaN
# 943                      http://www.caminomontessori.org          NaN
# 1114       http://ozark.cca.org/ozark-montessori.academy          NaN
# 1121                            http://www.prs.k12.ar.us          NaN
# 1151                                www.scaleacademy.org          NaN
# 1185                                   www.mmcharter.org          NaN
# 1269                               www.twinriversusd.org          NaN
# 1330                                     www.taylion.com          NaN
# 1346                                 www.goalsacademy.us          NaN
# 1529                                    www.ipakanni.com          NaN
# 1556                               www.sierracharter.org          NaN
# 1620                                                 NaN          NaN
# 1636                         www.juliancharterschool.org          NaN
# 1660                                                 NaN          NaN
# 1766                               www.haynescharter.com          NaN
# ...                                                  ...          ...
# 8909                                          http://mah          NaN
# 8920                                          http://www          NaN
# 8923                                                 NaN          NaN
# 8924                                                 NaN          NaN
# 8928                                                 NaN          NaN
# 8932                                                 NaN          NaN
# 8934                                                 NaN          NaN
# 8937                                                 NaN          NaN
# 8992                                          http://www          NaN
# 8999                                          www.leadpu          NaN
# 9073                                                 NaN          NaN
# 9074                                                 NaN          NaN
# 9160                                                 NaN       2015.0
# 9249                                                 NaN          NaN
# 9250                                                 NaN          NaN
# 9326                                                 NaN          NaN
# 9358                                                 NaN          NaN
# 9777                             www.orendaeducation.org          NaN
# 9877                                                 NaN          NaN
# 9879                                                 NaN          NaN
# 9880                                                 NaN          NaN
# 9966                                                 NaN          NaN
# 10014                                                NaN       2015.0
# 10100                                                NaN          NaN
# 10127                                       www.gisd.org          NaN
# 10233                      http://www.odysseycharter.net          NaN
# 10246                             www.successacademy.org          NaN
# 10294                  http://www.excelsior-academy.org/          NaN
# 10307                     http://www.alianzaacademy.org/          NaN
# 10530                             www.whitnall.com/core4          NaN
#
#                                            SCH_NAME  YEAR_OPENED
# 1                                               NaN       1999.0
# 5                                               NaN       1998.0
# 12                                              NaN       2007.0
# 16                                              NaN       1998.0
# 28                                              NaN       1998.0
# 32                                              NaN       2005.0
# 143       KINGMAN ACADEMY OF LEARNING - HIGH SCHOOL       2000.0
# 381                                             NaN       2013.0
# 443                                             NaN       1999.0
# 444                                             NaN       2008.0
# 569                                             NaN       2000.0
# 570                                             NaN       2000.0
# 724                                             NaN       2003.0
# 739                                             NaN       2003.0
# 785                                             NaN       2004.0
# 905                    LEADING EDGE ACADEMY SAN TAN       2012.0
# 943                                             NaN       2014.0
# 1114                                            NaN       2015.0
# 1121                                            NaN       2014.0
# 1151                                            NaN       2014.0
# 1185                                            NaN       2008.0
# 1269                                            NaN       2009.0
# 1330           TAYLION HIGH DESERT ACADEMY/ADELANTO       2013.0
# 1346                                            NaN       2015.0
# 1529                                            NaN       2010.0
# 1556                                            NaN       2006.0
# 1620                                            NaN       2016.0
# 1636                                            NaN       2000.0
# 1660                                            NaN       2002.0
# 1766                                            NaN       1998.0
# ...                                             ...          ...
# 8909                                            NaN       2014.0
# 8920            KIPP MEMPHIS COLLEGIATE HIGH SCHOOL       2014.0
# 8923             KIPP MEMPHIS COLLEGIATE ELEMENTARY       2014.0
# 8924                    KIPP MEMPHIS MIDDLE ACADEMY       2014.0
# 8928                                            NaN       2013.0
# 8932   DUBOIS ELEMENTARY SCHOOL OF ENTREPRENEURSHIP       2013.0
# 8934                                            NaN       2013.0
# 8937                                            NaN       2013.0
# 8992                                            NaN       2010.0
# 8999                            LEAD PREP SOUTHEAST       2012.0
# 9073                    ACCELERATED LEARNING CENTER       1999.0
# 9074                  GCCLR INSTITUTE OF TECHNOLOGY       2006.0
# 9160                                            NaN       1998.0
# 9249                      TEXAS EMPOWERMENT ACADEMY       1998.0
# 9250                   TEXAS EMPOWERMENT ACADEMY EL       2009.0
# 9326                                            NaN       1999.0
# 9358                                            NaN       1999.0
# 9777                                   NEW HORIZONS       2008.0
# 9877      BROOKS ACADEMY OF SCIENCE AND ENGINEERING       2006.0
# 9879           BROOKS INTERNATIONAL STUDIES ACADEMY       2014.0
# 9880                            BROOKS ACADEMY OAKS       2016.0
# 9966                                            NaN       2008.0
# 10014                                           NaN       2014.0
# 10100                                           NaN          NaN
# 10127                                    BURNET/ECU       2010.0
# 10233                        ODYSSEY CHARTER SCHOOL       2005.0
# 10246                                           NaN       2014.0
# 10294                                           NaN       2009.0
# 10307                                           NaN       2011.0
# 10530                                           NaN       2006.0
#
# [717 rows x 13 columns]

# %% [markdown]
# ## Save output

# %%
# Save DataFrame as CSV to data-management, web-scraping, and scrapy-cluster repos:
hasurl_df.to_csv('../../data_management/data/charters_unscraped_hasURL_2015.csv', index=False)
nourl_df.to_csv('../../data_management/data/charters_unscraped_noURL_2015.csv', index=False)

hasurl_df.to_csv('../../web_scraping/data/charters_unscraped_hasURL_2015.csv', index=False)
nourl_df.to_csv('../../web_scraping/data/charters_unscraped_noURL_2015.csv', index=False)

hasurl_df.to_csv('../../scrapy-cluster/kafka-monitor/charter_urls_2016_unscraped.csv', index=False)
nourl_df.to_csv('../../scrapy-cluster/kafka-monitor/charter_urls_2016_unscraped.csv', index=False)

# %%
#import
from bs4 import BeautifulSoup
import requests
import numpy as np
import json
import pickle

# %%
valid = "/Users/anhnguyen/Desktop/research/scraping_Python/text_files/valid_march.txt"
file = '/Users/anhnguyen/Desktop/research/scraping_Python/text_files/json.txt'

# %% [markdown]
# ### Helper Function

# %%
def write_file(str, file_name):
    """This function writes a string str to a given file name"""
    with open(file_name, "a") as text_file:
        text_file.write(str)
        
def read_txt(txt_file):
    """This function returns a list of all the lines of a file and also the count
    of how many lines"""
    links = []
    count = 0
    with open(txt_file) as f:
        for line in f:   
            count +=1
            links += [line.rstrip()]
    return links, count
def readtxt(txt_file):
    """This function returns a list of tuples and the count of lines
    each element of a tuple is separeted by tabtab
    example abc 123
            cdw 234
            return [(abc, 123), (cdw, 234)], 2"""
    links = []
    count = 0
    with open(txt_file) as f:
        for line in f:   
            elems = line.split('\t')
            #elem is a tuple (name, link)
            elem =  (elems[0].rstrip(), elems[1].rstrip())
            count +=1
            links += [elem]
    return links, count

# %%
# links, count = readtxt(valid)
# print(links[0][1])

# %%
url = 'https://www.polk.edu/lakeland-gateway-to-college-high-school/'
# credits: parsing team
def parse_data(url):
    
    data  = requests.get(url).text
    soup = BeautifulSoup(data, "lxml")
    hrefs = soup('a')
    paragraphs = soup('p')
    #only want unique hrefs
    links = []
    for each in hrefs:
        links.append(each.get('href'))
    links = set(links)
    return links, paragraphs
#TESTING
links, paragraphs = parse_data(url)

# %%
urlkey = ['about', 'department', 'home', 'community', 'life', 'curriculum', 'hist', 'phil', 'academics', 'moral', 'focus', 'beliefs', 'program', 'resources', 'mission', 'value', 'core']
urlkey = [s.upper() for s in urlkey]
#now parse through all of those links based on the key word search,
#and get a new list which contains the url's we actually want
# credits parsing team
def get_final_list(links):
    final_list = []
    for k in links:
        try:
            j = k.upper()
            for i in range(len(urlkey)):
                if isinstance(j, list) and len(j) == 1:
                    j = j[0].split(urlkey[i])
                elif isinstance(j, list) and len(j) > 1:
                    if requests.get(url + k):
                        final_list.append(k)
                        break
                else:
                    j = j.split(urlkey[i])
        except:
            pass

    final_list += ['/home']
    for i in range(len(final_list)):
        each = final_list[i].upper()
        # split with these keywords because we those pages with tag will not likely to give us 
        # the info we want
        k, m, n, o = each.split('FREQ'), each.split('ADMI'), each.split('TRUSTE'), each.split('ALUM')
        if len(k) > 1 or len(m) > 1 or len(n) > 1 or len(o) > 1:
            final_list[i] = '/home'
    final_list = set(final_list)
    return final_list

# TESTING
final_list = get_final_list(links)
print(final_list)
print(len(final_list))
# Out:
# {'https://www.polk.edu/lakeland-gateway-to-college-high-school/student-resources/', '/people/department/lakeland-gateway-to-college-high-school/', 'https://www.polk.edu/academics/', '/home', 'https://www.polk.edu/lakeland-gateway-to-college-high-school/about-us/', 'https://www.polk.edu/about/', 'https://www.polk.edu/community/', 'https://www.polk.edu/student-life/'}
# 8

# %%
#create a dictionary to for us to store our relevant texts into into 
#their respective categories
school = {'mission' : [], 'curriculum': [], 'philosophy' : [], 'history' : [], 'target' : [], 'resources' : [], 'organizational_factors' : []}
#key words for searching
k = [str(x) for x in np.arange(1900,2012)]
idk = ['advantage']
mission = ['mission',' vision ', 'our purpose', 'cause', 'objectives', 'vision:', 'mission:']
curriculum = ['curriculum', 'program', 'methods', 'pedagogy', 'approach', 'model',  'academics', 'degree']
philosophy = ['philosophy','beliefs', 'principles', 'creed', 'values',  'moral']
history = ['history', 'story', 'background', 'founded', 'established'] + k
target = ['target','gifted', 'at-risk', 'ethnic background', 'target population', 'target audience']
resources = ['resources', 'ESL', 'tutoring', 'after-school programs', 'available resources', 'services', 'opportunities', 'opportunity']
orgfactor = ['organizational_factors', 'statistics', 'API', 'environment', 'ratio', 'average', 'female', 'fund', 'community'  ]
keywords = [(mission[0], mission), (curriculum[0], curriculum), (philosophy[0], philosophy), (history[0], history), ( target[0],target) , (resources[0], resources), (orgfactor[0], orgfactor) ]

#makes all the text in uppercase
for i in range(0,len(keywords)):
    keywords[i] = (keywords[i][0], [s.upper() for s in keywords[i][1]])
keywords[0][1]
# Out:
# ['MISSION',
#  ' VISION ',
#  'OUR PURPOSE',
#  'CAUSE',
#  'OBJECTIVES',
#  'VISION:',
#  'MISSION:']

# %%
#create a mapper function to map the text which we parse through into 
#its relevant category in the dictionary
# credits: parsing team
def mapper(txt, school):
    
#     print(txt.upper())
    text = txt.upper()
    for i in range(len(keywords)):
        update_with_keyword(keywords[i], txt, school)
        
def update_with_keyword(keyword, txt, school):
    """This functions updates the school dict with txt
    keyword = field name, st mission, history, target, etc"""
    text1 = txt.upper()
#     print(keyword[1])
    for i in range(len(keyword[1])):
        if not isinstance(text1, list):
            text1 = text1.split(keyword[1][i])
        elif len(text1) == 1:
            text1 = text1[0].split(keyword[1][i])
        if len(text1) > 1:
#             print(keyword[0])
            school[keyword[0]].append(txt)
            break

# %%
def update_school_dict(final_list, school):
    for link in final_list:
        q = requests.get(url + link)
        k = q.text
        s = BeautifulSoup(k, "lxml")
        j = s.find_all('p')
        for lin in j:
            k = str(lin)
            if lin.get('class') == None and lin.get('a') == None and len(k.split('|')) == 1:
                mapper(' ' + lin.get_text(), school)
    # remove duplicates values with set
    updated_school = dict((k, set(v)) for k, v in school.items())
    return updated_school

# %%
# updated_school = update_school_dict(final_list, school)
# print(updated_school)

# %%
# print(updated_school['mission'])

# %%
def save_json(file, school):
    with open(file, 'wb') as outfile:
#         json.dump(school, outfile)
        pickle.dump(school, outfile)

# %%
count = 0
def run_master():
    
    #get the links, count of valid website links
    links, count = readtxt(valid)
    result = []
    #runing on first 3 sites
#     to_run = links[0:300]
    for url in links:
        
        
        name, link = url[0], url[1]
        print(link)
#         link = 'https://www.polk.edu/lakeland-gateway-to-college-high-school/'
        links, paragraphs = parse_data(link)
        final_list = get_final_list(links)
        #create a dictionary to for us to store our relevant texts into into 
        #their respective categories
        school = {'school_name': [], 'mission' : [], 'curriculum': [], 'philosophy' : [], 'history' : [], 'target' : [], 'resources' : [], 'organizational_factors' : []}
        try:
            updated_school = update_school_dict(final_list, school)
            updated_school['school_name'] = name
#             print(updated_school)
            print(str(count)+name)
            
            result.append(updated_school)
        except:
            pass
        
        count +=1
#         result[name] =updated_school
    save_json(file, result)

# %%
run_master()
# Out:
# https://www.richland2.org/charterhigh/
# 297RICHLAND TWO CHARTER HIGH
# https://www.polk.edu/lakeland-gateway-to-college-high-school/
# 298POLK STATE COLLEGE COLLEGIATE HIGH SCHOOL
# https://www.nhaschools.com/schools/rivercity/Pages/default.aspx
# 299RIVER CITY SCHOLARS CHARTER ACADEMY
# https://www.nhaschools.com/schools/detroitenterprise
# 300DETROIT ENTERPRISE ACADEMY
# https://www.lys.org/services/lighthouse-community-school/
# 301LIGHTHOUSE COMMUNITY SCH INC
# https://westlakecharter.com
# 302WESTLAKE CHARTER MIDDLE
# https://vangoghcs-lausd-ca.schoolloop.com/
# 303VAN GOGH CHARTER
# https://summitacademies.org/schools/dayton-high/
# 304SUMMIT ACADEMY TRANSITION HIGH SCHOOL DAYTON
# https://cms.springbranchisd.com/wais/
# 305WESTCHESTER ACADEMY FOR INTERNATIONAL STUDIES
# https://cityacademy.org/
# 306CITY ACADEMY
# https://byrnes-ecsd-fl.schoolloop.com/
# 307BYRNEVILLE ELEMENTARY SCHOOL, INC.
# https://acaciamiddle.org/
# 308ACACIA MIDDLE CHARTER
# http://www2.milwaukee.k12.wi.us/whittier/whittier.htm
# 309WHITTIER ELEMENTARY
# http://www.zoelearningcenters.com
# 310ZOE LEARNING ACAD - AMBASSADOR CAMPUS
# http://www.ywlcs.org/
# 311YOUNG WOMENS LEADERSHIP CHARTR HS
# http://www.yuba.net/
# 312YUBA COUNTY CAREER PREPARATORY CHARTER
# http://www.ysacs.org/
# 313YOUNG SCHOLARS OF WESTERN PENNSYLVANIA C
# http://www.wpaces.org/
# 314WEST PHILA. ACHIEVEMENT CES
# http://www.woodcharter.com/Granbury/
# 315JOHN H WOOD JR CS GRANBURY
# http://www.willowcreekcharter.com/
# 316WILLOW CREEK CHARTER SCHOOL
# http://www.whitepineacademy.com/
# 317WHITE PINE ACADEMY
# http://www.westridgeacademycharter.com/
# 318WEST RIDGE ACADEMY
# http://www.wattslearningcenter.org/
# 319WATTS LEARNING CENTER CHARTER MIDDLE
# http://www.waterfordmontessori.org/
# 320WATERFORD MONTESSORI ACADEMY
# http://www.vlcs.org/
# 321VALLEY LIFE CHARTER
# http://www.valleycharterschool.org/
# 322VALLEY CHARTER ELEMENTARY
# http://www.valcharter.org/
# 323VIRTUAL ACADEMY OF LAFOURCHE
# http://www.urbanprep.org/
# 324URBAN PREP CHTR ACAD BRONZEVILLE HS
# http://www.tworiverscommunityschool.net/
# 325TWO RIVERS COMMUNITY SCHOOL
# http://www.twodimensions.org/
# 326TWO DIMENSIONS/VICKERY
# http://trinitysfc.org/
# 327TRINITY SCHOOL FOR CHILDREN
# http://www.tlca-cl.com/
# 328TEXAS LEADERSHIP OF MIDLAND
# http://www.tisataos.com/
# 329TAOS INTEGRATED SCHOOL OF ARTS
# http://www.thestemacademy.us/index.html
# 330CINCINNATI STATE STEM ACADEMY
# http://www.themanaacademy.org/
# 331MANA ACADEMY CHARTER SCHOOL
# http://www.thegreenschoolofbaltimore.org/
# 332THE GREEN SCHOOL
# http://www.ntxca.org/vnews/display.v/SEC/South%20Campus
# 333THE EDUCATION CENTER IN LEWISVILLE
# http://www.theabowmanacademy.org/
# 334THEA BOWMAN LEADERSHIP ACADEMY
# http://www.texanscan.org/schools-and-programs/fort-worth-westcreek/
# 335FORT WORTH CAN ACADEMY - SOUTH
# http://www.texanscan.org/schools-and-programs/dallas-ross-avenue/
# http://www.telesis-academy.org/
# http://www.teccs-jc.org/
# 338ETHICAL COMMUNITY CHARTER SCHOOL (THE)
# http://www.tapestryschool.org/
# 339TAPESTRY CHARTER SCHOOL
# http://www.tapaprovidence.org/
# 340TRINITY ACADEMY PERFORMING ART
# http://www.swschools.org/
# 341SOUTHWEST SCHOOLS MANGUM EL CAMPUS
# http://www.swprep.org/
# 342SOUTHWEST PREPARATORY SCHOOL-NORTHWEST
# http://www.sunvalleycharterschool.com/
# 343SUN VALLEY CHARTER SCHOOL
# http://www.sunnywolfcharterschool.com/
# 344SUNNY WOLF CHARTER SCHOOL
# http://www.suncoastschool.org/
# 345SUNCOAST SCHOOL FOR INNOVATIVE STUDIES
# http://www.summiths.com/
# 346KAIZEN EDUCATION FOUNDATION DBA SUMMIT HIGH SCHOOL
# http://www.striveprep.org/school/strive-prep-smart-academy/
# 347STRIVE PREP - SMART ACADEMY
# http://www.sthopeleadershipacademy.org/
# 348ST HOPE LEADERSHIP ACADEMY CHARTER SCHOOL
# http://www.stcroixprep.org/
# 349ST CROIX PREPARATORY ACADEMY MIDDLE
# http://www.spacharter.org/
# 350STONY POINT ACADEMY
# http://www.southsideedu.org/
# 351SOUTHSIDE ACADEMY
# http://www.southpointehs.com/
# 352SOUTH POINTE HIGH SCHOOL
# http://www.southbronxclassical.org/
# 353SOUTH BRONX CLASSICAL CHARTER SCHOOL II
# http://www.somersetdc.com/
# 354SOMERSET PREPARATORY ACADEMY PCS
# http://www.somersetacademy.com/
# 355SOMERSET ACADEMY CHARTER HIGH
# http://www.slacs-phila.org/
# 356SOUTHWEST LEADERSHIP ACADEMY CS
# http://www.simontechnology.org/
# 357ALLIANCE CINDY AND BILL SIMON TECHNOLOGY ACADEMY H
# http://www.siatech.org/
# 358SCHOOL FOR INTEGRATED ACADEMICS AND TECHNOLOGIES
# http://www.shiloh.k12.ca.us/
# 359SHILOH CHARTER
# http://www.shawanoschools.com/schools/leads/
# 360LEADS PRIMARY CHARTER SCHOOL
# http://www.sequoiavillageschool.org/
# 361SEQUOIA VILLAGE SCHOOL
# http://www.seedschooldc.org/
# 362SEED PCS OF WASHINGTON DC
# http://www.sdccs.org/
# 363SAN DIEGO COOPERATIVE CHARTER
# http://www.sauvieislandacademy.org/
# 364SAUVIE ISLAND ACADEMY
# http://www.sanger.k12.ca.us/
# 365SANGER ACADEMY CHARTER
# http://www.sage-academy.org/
# 366SAGE ACADEMY
# http://www.rivervalleyhigh.org/
# 367RIVER VALLEY CHARTER
# http://east.riverside-academy.net/
# 368RIVERSIDE ACADEMY
# http://www.rivercityscience.org/
# 369RIVER CITY SCIENCE ACADEMY INNOVATION SCHOOL
# http://www.richardallenla.com/
# 370RICHARD ALLEN LEADERSHIP ACADEMY
# http://www.renaissancecharter.org/
# 371RENAISSANCE CHARTER SCHOOL AT TRADITION
# http://www.relevantacademy.org/
# 372RELEVANT ACADEMY OF EATON COUNTY
# http://www.rapoportacademy.org/
# 373RAPOPORT ACADEMY EL - NORTH CAMPUS
# http://www.questpeoria.org/
# 374QUEST CHARTER SCHOOL ACADEMY
# http://www.pvcics.org/
# 375PIONEER VALLEY CHINESE IMMERSION CHARTER SCHOOL
# http://www.putnamacademy.org/
# 376PUTNAM ACADEMY OF ARTS AND SCIENCES
# http://www.providencehall.com/
# 377PROVIDENCE HALL
# http://www.promiseacademycharter.org/pride/
# 378CAMDEN'S PRIDE CHARTER SCHOOL
# http://www.prestigeacademycs.org/
# 379PRESTIGE ACADEMY
# http://www.portage.k12.wi.us/
# 380PORTAGE ACADEMY OF ACHIEVEMENT
# http://www.berkleymiddle.net
# 381BERKLEY ACCELERATED MIDDLE SCHOOL
# http://www.pickerington.k12.oh.us/
# 382PICKERINGTON COMMUNITY SCHOOL
# http://www.performanceacademies.com/
# 383COLUMBUS PERFORMANCE ACADEMY
# http://www.peakschool.org/
# 384THE PEAK SCHOOL
# http://www.vulturepeak.wickenburgschools.org
# 385VULTURE PEAK MIDDLE SCHOOL
# http://www.pdc.k12.wi.us/mightyriver/
# 386MIGHTY RIVER ACADEMY OF VIRTUAL EDUCATION
# http://www.rosebudacademy.com
# 387PASADENA ROSEBUD ACADEMY MIDDLE
# http://www.palmettocharterschool.org/
# 388PALMETTO CHARTER SCHOOL
# http://www.palcs.org/
# 389PENNSYLVANIA LEADERSHIP CS
# http://www.nycmcs.org/
# 390NEW YORK CITY MONTESSORI CHARTER SCHOOL
# http://www.northwoodcs.org/
# 391NORTHWOOD ACADEMY CS
# http://www.northlakesacademy.org/
# 392NORTH LAKES ACADEMY
# http://www.noccs.org/
# 393NORTH OAKLAND COMMUNITY CHARTER
# http://www.nobleacademy.us/
# 394NOBLE ACADEMY
# http://www.newworldprep.org/
# 395NEW WORLD PREPARATORY CHARTER SCHOOL
# http://www.newheightscharter.org/
# 396NEW HEIGHTS CHARTER
# http://www.newcastle.k12.ca.us/
# 397NEWCASTLE CHARTER
# http://www.ncsota.org/
# 398NEVADA CITY SCHOOL OF THE ARTS
# http://www.mycompassacademy.org/
# 399COMPASS ACADEMY CHARTER SCHOOL
# http://www.monumentacademy.net/
# 400MONUMENT CHARTER ACADEMY
# http://www.montedelsol.org/
# 401MONTE DEL SOL CHARTER
# http://www.mnohs.org/
# 402MINNESOTA ONLINE HIGH SCHOOL
# http://www.mninternationalmiddleschool.org/
# http://www.mmcharter.org/
# https://www.minisacademy.org
# http://www.memphiscollegeprep.org/
# http://www.mckeelelementary.com/
# http://www.materlakes.org/
# http://www.materacademy.com/project/mater-brickell-preparatory-academy-k-8/
# http://www.matchschool.org/
# http://www.marshallacademy.org/
# http://www.magonacademy.org/
# http://www.magellancharter.org/
# http://www.lockhurstelementary.com/
# http://www.liveoakcharter.org/
# http://www.lisanorth.org/
# http://www.lifeskillscenters.com/
# http://www.leonagroup.com/
# http://www.leadingedgeacademy.com/mountain-view/
# http://www.lawschoolbus.com/
# http://www.lawrenceacademy.net/
# http://www.lakeview-academy.com/
# http://www.lakecountryacademy.com/
# http://www.lake.k12.fl.us/Domain/4026
# http://www.lafayetteacademyno.org/
# http://www.ladylibertyacademycs.org/
# 426LADY LIBERTY ACADEMY CHARTER SCHOOL
# http://www.lacausa.org/
# 427LA CAUSA CHARTER SCHOOL
# http://www.kippreach.org/
# 428KIPP REACH COLLEGE PREPARATORY
# http://www.kippmetroatlanta.org/kipp-ways-academy/
# 429KIPP WEST ATLANTA YOUNG SCHOLARS ACADEMY
# http://www.kippmetroatlanta.org/kipp-vision-primary/
# 430KIPP VISION PRIMARY
# http://www.kippmemphis.org/apps/pages/index.jsp?uREC_ID=242740&type=d
# 431KIPP MEMPHIS MIDDLE ACADEMY
# http://www.kippbayarea.org/schools/sjcollegiate/
# 432KIPP SAN JOSE COLLEGIATE
# http://www.kippbayarea.org/schools/sfcollegeprep/
# 433KIPP SAN FRANCISCO COLLEGE PREPARATORY
# http://www.kippbayarea.org/schools/heartwood/
# 434KIPP HEARTWOOD ACADEMY
# http://www.kawaikini.com/
# 435KAWAIKINI NCPCS
# http://www.k12northstar.org/starofthenorth
# 436STAR OF THE NORTH SECONDARY SCHOOL
# http://www.k12northstar.org/chinook
# 437CHINOOK MONTESSORI CHARTER SCHOOL
# http://www.jklschool.org/
# 438JOSEPH K. LUMSDEN BAHWETING ANISHNABE ACADEMY
# http://www.janesville.k12.wi.us/
# 439JANESVILLE VIRTUAL ACADEMY
# http://www.ivyprepacademy.org/
# 440IVY PREPARATORY YOUNG MEN'S LEADERSHIP ACADEMY SCH
# http://www.iusd.net/
# 441CITY HONORS COLLEGE PREPARATORY CHARTER
# http://www.irra.org/
# 442IGNITE PUBLIC SCH AND COMM SERV CTR AT WESLACO
# http://www.invictushigh.org/
# 443INVICTUS HIGH SCHOOL
# http://www.interculturalacademy.com/
# 444FLORIDA INTERCULTURAL ACADEMY
# http://www.intellischool.org/
# 445INTELLI-SCHOOL - PARADISE VALLEY
# http://www.imaginecoolidge.com/
# 446IMAGINE COOLIDGE ELEMENTARY
# http://www.igenacademy.org/
# 447IGENERATION EMPOWERMENT ACADEMY
# http://www.ideapublicschools.com/
# 448IDEA QUEST ACADEMY
# http://www.icanschools.org/lake-erie-preparatory-school
# 449LAKE ERIE COLLEGE PREPARATORY SCHOOL
# http://www.hustonacademy.com/
# 450HUSTON ACADEMY
# http://www.husd.org/cooley
# 451COOLEY MIDDLE SCHOOL
# http://www.humespa.org/
# 452HUMES PREPARATORY ACADEMY - UPPER SCHOOL
# http://www.houstonisd.org/Domain/22641
# 453CHALLENGE EARLY COLLEGE H S
# http://www.hilltowncharter.org/
# 454HILLTOWN COOPERATIVE CHARTER PUBLIC SCHOOL
# http://www.hightechhigh.org/schools/HTHCV/
# 455HIGH TECH MIDDLE CHULA VISTA
# http://www.heightsprep.org/
# 456UPLIFT EDUCATION - HEIGHTS PREP PRI
# http://www.healthscienceschool.org/
# 457DR RICHARD IZQUIERDO HEALTH AND SCIENCE CHARTER SC
# http://www.greenwoodscharter.org/
# 458GREEN WOODS CS
# http://ca.greendot.org/westside/
# 459ANIMO WESTSIDE CHARTER MIDDLE
# http://www.grantleadership.com/
# 460C.M. GRANT LEADERSHIP ACADEMY
# http://www.goldenruledallas.org/apps/pages/index.jsp?uREC_ID=88337&type=d&pREC_ID=178530&hideMenu=1
# 461GOLDEN RULE SOUTHWEST
# http://www.glcps.org/
# 462GLOBAL LEARNING CHARTER PUBLIC SCHOOL
# http://www.glasscityacademy.org/
# 463GLASS CITY ACADEMY
# http://www.galschools.org/
# 464GIRLS ATHLETIC LEADERSHIP SCHOOL
# http://www.fwsafe.com/
# 465SMITH ACADEMY FOR EXCELLENCE
# http://www.focusacademytampa.org/
# 466FOCUS ACADEMY
# http://www.fjacademy.com/
# 467FLAGSTAFF JUNIOR ACADEMY
# http://www.ferris.edu/charterschools
# 468HOPE OF DETROIT ACADEMY CONSORTIUM HIGH SCHOOL
# http://www.fallbrookcpa.org/
# 469FALLBROOK COLLEGE PREPARATORY ACADEMY
# http://www.evergladesprep.com/pages/Everglades_Preparatory_Academy
# 470EVERGLADES PREPARATORY ACADEMY HIGH SCHOOL
# http://www.eelriverschool.net/
# 471EEL RIVER CHARTER
# http://unitycsfm.org
# 472FORT MYERS PREPARATORY AND FITNESS ACADEMY
# http://www.edlinesites.net/pages/Vantage_Point_Charter/
# 473VANTAGE POINT CHARTER
# http://www.echo.charter.k12.mn.us/
# 474E.C.H.O. CHARTER SCHOOL
# http://www.eastprep.org/
# 475EAST PREPARATORY ACADEMY
# http://www.eagletoledo.com/
# 476EAGLE ACADEMY
# http://www.eagleridgeacademy.net/
# 477EAGLE RIDGE ACADEMY CHARTER SCHOOL
# http://www.e-institute.us/locations/surprise/
# 478E-INSTITUTE AT SURPRISE
# http://www.e-institute.us/
# 479E-INSTITUTE AT GROVERS
# http://www.dlachampion.org
# 480DETROIT LEADERSHIP ACADEMY MIDDLE/HIGH
# http://www.dignidad.org/
# 481XINAXCALMECAC ACADEMIA SEMILLAS DEL PUEBLO
# http://www.dcprep.org/Benning_Elementary_Campus
# 482D C PREP BENNING ELEMENTARY PCS
# http://www.davidellisacademy.com/
# 483DAVID ELLIS ACADEMY
# http://www.crossroadscharter.org/
# 484CROSSROADS CHARTER HIGH
# http://www.crossnoreschool.org/
# 485CROSSNORE ACADEMY
# http://www.cpdlf.org/
# 486CENTRAL PA DIGITAL LRNG FOUNDATION CS
# http://www.corvian.org/
# 487CORVIAN COMMUNITY SCHOOL
# http://www.corebutte.org/
# 488CORE BUTTE CHARTER
# http://www.coralacademy.org/
# 489CORAL ACADEMY CHARTER SCHOOL SECONDARY
# http://www.connectionsacademy.com/nevada-virtual-school/
# 490NEVADA CONNECTIONS ACADEMY
# http://www.confluenceacademy.com/
# http://www.compassmontessori.org/
# http://www.classicalacademy.com/coastal/
# http://www.cityonahill.org/
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Users/anhnguyen/anaconda3/lib/python3.4/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     141             conn = connection.create_connection(
# --> 142                 (self.host, self.port), self.timeout, **extra_kw)
#     143
#
# /Users/anhnguyen/anaconda3/lib/python3.4/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      74
# ---> 75     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      76         af, socktype, proto, canonname, sa = res
#
# /Users/anhnguyen/anaconda3/lib/python3.4/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     536     addrlist = []
# --> 537     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     538         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /Users/anhnguyen/anaconda3/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     594                                                   body=body, headers=headers,
# --> 595                                                   chunked=chunked)
#     596
#
# /Users/anhnguyen/anaconda3/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     362         else:
# --> 363             conn.request(method, url, **httplib_request_kw)
#     364
#
# /Users/anhnguyen/anaconda3/lib/python3.4/http/client.py in request(self, method, url, body, headers)
#    1136         """Send a complete request to the server."""
# -> 1137         self._send_request(method, url, body, headers)
#    1138
#
# /Users/anhnguyen/anaconda3/lib/python3.4/http/client.py in _send_request(self, method, url, body, headers)
#    1181             body = body.encode('iso-8859-1')
# -> 1182         self.endheaders(body)
#    1183
#
# /Users/anhnguyen/anaconda3/lib/python3.4/http/client.py in endheaders(self, message_body)
#    1132             raise CannotSendHeader()
# -> 1133         self._send_output(message_body)
#    1134
#
# /Users/anhnguyen/anaconda3/lib/python3.4/http/client.py in _send_output(self, message_body)
#     962             message_body = None
# --> 963         self.send(msg)
#     964         if message_body is not None:
#
# /Users/anhnguyen/anaconda3/lib/python3.4/http/client.py in send(self, data)
#     897             if self.auto_open:
# --> 898                 self.connect()
#     899             else:
#
# /Users/anhnguyen/anaconda3/lib/python3.4/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     166     def connect(self):
# --> 167         conn = self._new_conn()
#     168         self._prepare_conn(conn)
#
# /Users/anhnguyen/anaconda3/lib/python3.4/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     150             raise NewConnectionError(
# --> 151                 self, "Failed to establish a new connection: %s" % e)
#     152
#
# NewConnectionError: <requests.packages.urllib3.connection.HTTPConnection object at 0x108ae2320>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /Users/anhnguyen/anaconda3/lib/python3.4/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# /Users/anhnguyen/anaconda3/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     639             retries = retries.increment(method, url, error=e, _pool=self,
# --> 640                                         _stacktrace=sys.exc_info()[2])
#     641             retries.sleep()
#
# /Users/anhnguyen/anaconda3/lib/python3.4/site-packages/requests/packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     286         if new_retry.is_exhausted():
# --> 287             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     288
#
# MaxRetryError: HTTPConnectionPool(host='www.cityonahill.org', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x108ae2320>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-16-cd5ab53aeb45> in <module>()
# ----> 1 run_master()
#
# <ipython-input-15-f2d2afb07806> in run_master()
#      13         print(link)
#      14 #         link = 'https://www.polk.edu/lakeland-gateway-to-college-high-school/'
# ---> 15         links, paragraphs = parse_data(link)
#      16         final_list = get_final_list(links)
#      17         #create a dictionary to for us to store our relevant texts into into
#
# <ipython-input-5-010f35e9ddc7> in parse_data(url)
#       2 # credits: parsing team
#       3 def parse_data(url):
# ----> 4     data  = requests.get(url).text
#       5     soup = BeautifulSoup(data, "lxml")
#       6     hrefs = soup('a')
#
# /Users/anhnguyen/anaconda3/lib/python3.4/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /Users/anhnguyen/anaconda3/lib/python3.4/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /Users/anhnguyen/anaconda3/lib/python3.4/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# /Users/anhnguyen/anaconda3/lib/python3.4/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     594
#     595         # Send the request
# --> 596         r = adapter.send(request, **kwargs)
#     597
#     598         # Total elapsed time of the request (approximately)
#
# /Users/anhnguyen/anaconda3/lib/python3.4/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='www.cityonahill.org', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x108ae2320>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))

# %%
#want the obj back
def get_obj_back(file):
    with open(file,'rb') as f:
        var = pickle.load(f)
    return var
